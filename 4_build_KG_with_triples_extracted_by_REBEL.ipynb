# %% [markdown]
# ### 4. KG Building Notebook
#
# ##### In this notebook, we:
# 1. call the graph object.
# 2. define two namespaces and bind them to the graph:
#     * RBL = Namespace("http://example.org/rebel/#")
#     * WIKI = Namespace("https://www.wikidata.org/wiki/")
# 3. make entity triples and add them to the graph:
#     * (ent, RDF.type, RDFS.Resource)
#     * (ent, RDF.type, RBL.Entity)
#     * (ent, RDFS.label, Literal(key))
#     * (ent, WIKI.id, Literal(value))
#     * (ent, OWL.sameAs, wiki_ent)
# 4. make relation triples and add them to the graph:
#     * (rel, RDF.type, RDF.Property)
#     * (rel, RDF.type, RBL.Relation)
#     * (rel, WIKI.type, WIKI.Property)
#     * (rel, RDFS.label, Literal(key))
#     * (rel, WIKI.id, Literal(value))
#     * (rel, OWL.sameAs, wiki_rel)
# 5. add more semantics:
#     * (RDF.type, OWL.equivalentProperty, WIKI.P31)
#     * (RDFS.subClassOf, OWL.equivalentProperty, WIKI.P279)
#     * (RDFS.subPropertyOf, OWL.equivalentProperty, WIKI.P1647)
#     * (RDFS.member, OWL.equivalentProperty, WIKI.P361)
# 6. add the triples, both REBEL and Wikidata, to the graph
#     * (URIRef(WIKI + triple[0]), URIRef(WIKI + triple[1]), URIRef(WIKI + triple[2]))
#     * (URIRef(RBL + subj), URIRef(RBL + pred), URIRef(RBL + obj))
# 7. serialize the grap in ttl format and save it.

# %%
# we start with imports
from rdflib import Graph, URIRef, Literal, Namespace
from rdflib.namespace import RDFS, RDF, OWL
import json
import string

# %%
# Let's define some namespaces
RBL = Namespace("http://example.org/rebel/#")
WIKI = Namespace("https://www.wikidata.org/wiki/")

g = Graph() # create a graph object
g.bind("rebel", RBL,  override=True) # bind the rebel namespace to the graph
g.bind("wiki", WIKI, override=True) # bind the wiki namespace to the graph

# %%
# Let's rememeber how the library works and decide how to put into the correct format
ent = "The Beatles"
ent = ent.lower().replace(' ', '_')
ent = URIRef(RBL + ent)
print(type(ent))
print(ent)
# Out:
# <class 'rdflib.term.URIRef'>
# http://example.org/rebel/#the_beatles

# %%
# let's shape the relation names
rel = 'instance of'.lower().split()
if len(rel) > 1:
    words = []
    for index, word in enumerate(rel):
        if (index % 2) == 0:
            word = word.lower()   
        else:
            word = word.capitalize()
                    
        words.append(word)
    rel = ''.join(words)
rel =  URIRef(RBL + rel)
print(rel)
# Out:
# http://example.org/rebel/#instanceOf

# %%
#First we get the entities, relations and the wikidata ids from the dictionaries.
#Then we create the triples and add them to the graph.

with open('data/rebel_wiki_entities_dict.json', 'r', encoding='utf-8') as f:
    entities = json.load(f)
print(len(entities))
#print(entities)

with open('data/rebel_wiki_relations_dict.json', 'r', encoding='utf-8') as f:
    relations = json.load(f)
print(len(relations))
#print(relations)
# Out:
# 3738
# 157

# %%
# we create the entity triples: type: rebel:Entity, label: entity name, id: wikidata id, sameAs: wikidata uri
for key, value in entities.items():
    ent = key.translate(str.maketrans('', '', string.punctuation))
    ent = ent.lower().replace(' ', '_')
    ent = URIRef(RBL + ent)
    wiki_ent = URIRef(WIKI + value)
    #print(ent)
    g.add((ent, RDF.type, RDFS.Resource))
    g.add((ent, RDF.type, RBL.Entity))
    g.add((ent, RDFS.label, Literal(key)))
    g.add((ent, WIKI.id, Literal(value)))
    g.add((ent, OWL.sameAs, wiki_ent))

# %%
# we create the relation triples: type: rebel:Relation, label: relation name, id: wikidata id, sameAs: wikidata uri
for key, value in relations.items():
    #print(key)
    rel = key.translate(str.maketrans('', '', string.punctuation))
    rel = rel.lower().split()
    #print(rel)
    if len(rel) > 1:
        words = []
        for index, word in enumerate(rel):
            #print(index, word)
            if (index % 2) == 0:
                word = word.lower()   
            elif (index % 2) == 1:
                word = word.capitalize()         
            words.append(word)
        rel = ''.join(words)
    else:
        rel = rel[0]
    #print(rel)
    rel = URIRef(RBL + rel)
    wiki_rel = URIRef(WIKI + value)
    #print(rel)
    g.add((rel, RDF.type, RDF.Property))
    g.add((rel, RDF.type, RBL.Relation))
    g.add((rel, WIKI.type, WIKI.Property))
    g.add((rel, RDFS.label, Literal(key)))
    g.add((rel, WIKI.id, Literal(value)))
    g.add((rel, OWL.sameAs, wiki_rel))

# %%
#Let's add more semantics for the reasoners: e.g. equivalent properties

g.add((RDF.type, OWL.equivalentProperty, WIKI.P31))
g.add((RDFS.subClassOf, OWL.equivalentProperty, WIKI.P279))
g.add((RDFS.subPropertyOf, OWL.equivalentProperty, WIKI.P1647))
g.add((RDFS.member, OWL.equivalentProperty, WIKI.P361))
# Out:
# <Graph identifier=N761d051a453c467e8a917e3a8da23206 (<class 'rdflib.graph.Graph'>)>

# %%
# Let's add the triples to the graph
data = []
with open('data/preprocessed_data_with_REBEL_extracted_triples_plus_wikidata.jsonl', 'r', encoding='utf-8') as f:
    for line in f:
        data.append(json.loads(line.rstrip('None\n')))
print(len(data))
# Out:
# 917

# %%
# We start with wikidata triples
for line in data:
    wiki_triples = line["Wikidata Triples"]
    for triple in wiki_triples:
        new_triples = (URIRef(WIKI + triple[0]), URIRef(WIKI + triple[1]), URIRef(WIKI + triple[2]))
        g.add(new_triples)

# %%
# Let's add the REBEL triples

for line in data:
    rebel_triples = line["Extracted Triples"]
    for triple in rebel_triples:
        subj = triple[0].translate(str.maketrans('', '', string.punctuation))
        subj = subj.lower().replace(' ', '_')
        pred = triple[1].translate(str.maketrans('', '', string.punctuation)).split()
        if len(pred) > 1:
            words = []
            for index, word in enumerate(pred):
                #print(index, word)
                if (index % 2) == 0:
                    word = word.lower()   
                elif (index % 2) == 1:
                    word = word.capitalize()         
                words.append(word)
            pred = ''.join(words)
        else:
            pred = pred[0]
        #print(pred)
        obj = triple[2].translate(str.maketrans('', '', string.punctuation))
        obj = obj.lower().replace(' ', '_')
        new_triples = (URIRef(RBL + subj), URIRef(RBL + pred), URIRef(RBL + obj))
        #print(new_triples)
        g.add(new_triples)

# %%
# let's have a look at the graph
print(g.serialize())
# Out:
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix rebel: <http://example.org/rebel/#> .
# @prefix wiki: <https://www.wikidata.org/wiki/> .
#
# rebel:100_meter_sprint_final a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "100 meter sprint final" ;
#     rebel:partOf rebel:1960_summer_olympics ;
#     rebel:participant rebel:armin_hary ;
#     rebel:pointIntime rebel:1960 ;
#     rebel:winner rebel:armin_hary ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:12_preexisting_formal_palestinian_refugee_camps a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "12 pre-existing formal Palestinian refugee camps" ;
#     rebel:country rebel:lebanon ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:12_preexisting_formal_palestinian_refugee_camps_in_lebanon a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "12 pre-existing formal Palestinian refugee camps in Lebanon" ;
#     rebel:operator rebel:unrwa ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:14701_aizu a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "14701 Aizu" ;
#     rebel:siteOfastronomicalDiscovery rebel:lowell_observatory ;
#     owl:sameAs wiki:Q3597470 ;
#     wiki:id "Q3597470" .
#
# rebel:14901_aizu a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "14901 Aizu" ;
#     rebel:siteOfastronomicalDiscovery rebel:lowell_observatory ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:1755_cape_ann a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "1755 Cape Ann" ;
#     rebel:instanceOf rebel:earthquake ;
#     owl:sameAs wiki:Q4552913 ;
#     wiki:id "Q4552913" .
#
# rebel:180tbwa a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "180/TBWA" ;
#     rebel:headquartersLocation rebel:amsterdam ;
#     rebel:locationOfformation rebel:amsterdam ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:1811 a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "1811" ;
#     rebel:instanceOf rebel:earthquake ;
#     owl:sameAs wiki:Q6928 ;
#     wiki:id "Q6928" .
#
# <http://example.org/rebel/#1811–12_new_madrid> a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "1811–12 New Madrid" ;
#     rebel:instanceOf rebel:earthquake ;
#     owl:sameAs wiki:Q20018875 ;
#     wiki:id "Q20018875" .
#
# rebel:1812_san_juan_capistrano a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "1812 San Juan Capistrano" ;
#     rebel:pointIntime rebel:1812 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:1857_event a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "1857 event" ;
#     rebel:pointIntime rebel:1857 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:1857_event_on_the_main_saf a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "1857 event on the main SAF" ;
#     rebel:pointIntime rebel:1857 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:1857_fort_tejon a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "1857 Fort Tejon" ;
#     rebel:pointIntime rebel:1857 ;
#     owl:sameAs wiki:Q477444 ;
#     wiki:id "Q477444" .
#
# rebel:1872_owens_valley_shock a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "1872 Owens Valley shock" ;
#     rebel:pointIntime rebel:1872 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:1886_charleston a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "1886 Charleston" ;
#     rebel:instanceOf rebel:earthquake,
#         rebel:earthquakes ;
#     rebel:pointIntime rebel:1886 ;
#     owl:sameAs wiki:Q477519 ;
#     wiki:id "Q477519" .
#
# rebel:19534_miyagi a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "19534 Miyagi" ;
#     rebel:siteOfastronomicalDiscovery rebel:lowell_observatory ;
#     owl:sameAs wiki:Q3597894 ;
#     wiki:id "Q3597894" .
#
# rebel:19691_iwate a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "19691 Iwate" ;
#     rebel:siteOfastronomicalDiscovery rebel:lowell_observatory ;
#     owl:sameAs wiki:Q3597897 ;
#     wiki:id "Q3597897" .
#
# rebel:19701_aomori a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "19701 Aomori" ;
#     rebel:siteOfastronomicalDiscovery rebel:lowell_observatory ;
#     owl:sameAs wiki:Q3597898 ;
#     wiki:id "Q3597898" .
#
# rebel:19713_ibaraki a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "19713 Ibaraki" ;
#     rebel:siteOfastronomicalDiscovery rebel:lowell_observatory ;
#     owl:sameAs wiki:Q3597899 ;
#     wiki:id "Q3597899" .
#
# rebel:19731_tochigi a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "19731 Tochigi" ;
#     rebel:siteOfastronomicalDiscovery rebel:lowell_observatory ;
#     owl:sameAs wiki:Q3597900 ;
#     wiki:id "Q3597900" .
#
# rebel:1976_level a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "1976 level" ;
#     rebel:pointIntime rebel:1976 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:1976_report a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "1976 report" ;
#     rebel:author rebel:united_states_national_academy_of_sciences ;
#     rebel:publisher rebel:united_states_national_academy_of_sciences ;
#     owl:sameAs wiki:Q68274132 ;
#     wiki:id "Q68274132" .
#
# rebel:1977_levels a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "1977 levels" ;
#     rebel:pointIntime rebel:1977 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:1980s a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "1980s" ;
#     rebel:pointIntime rebel:1980 ;
#     owl:sameAs wiki:Q34644 ;
#     wiki:id "Q34644" .
#
# rebel:1990s a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "1990s" ;
#     rebel:pointIntime rebel:1990 ;
#     owl:sameAs wiki:Q34653 ;
#     wiki:id "Q34653" .
#
# rebel:1991_eruption a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "1991 eruption" ;
#     rebel:instanceOf rebel:volcanic_eruption,
#         rebel:volcanic_eruptions ;
#     rebel:pointIntime rebel:1991 ;
#     owl:sameAs wiki:Q31191031 ;
#     wiki:id "Q31191031" .
#
# rebel:1991_eruption_of_mt_fuji a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "1991 eruption of Mt. Fuji" ;
#     rebel:instanceOf rebel:volcanic_eruptions ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:1991_eruption_of_mt_vernon a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "1991 eruption of Mt. Vernon" ;
#     rebel:instanceOf rebel:volcanic_eruption,
#         rebel:volcanic_eruptions ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:1991_eruption_of_mt_vesuvius a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "1991 eruption of Mt. Vesuvius" ;
#     rebel:instanceOf rebel:volcanic_eruption,
#         rebel:volcanic_eruptions ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:1994_northridge_earthquake a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "1994 Northridge earthquake" ;
#     rebel:locatedIntheAdministrativeterritorialEntity rebel:southern_california ;
#     rebel:pointIntime rebel:1994 ;
#     owl:sameAs wiki:Q1519015 ;
#     wiki:id "Q1519015" .
#
# rebel:1995_nobel_prize_in_chemistry a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "1995 Nobel Prize in Chemistry" ;
#     rebel:pointIntime rebel:1995 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:1997_unep_award a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "1997 UNEP award" ;
#     rebel:pointIntime rebel:1997 ;
#     rebel:winner rebel:greenpeace ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:1_fc_herzogenaurach a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "1 FC Herzogenaurach" ;
#     rebel:headquartersLocation rebel:herzogenaurach ;
#     rebel:locatedIntheAdministrativeterritorialEntity rebel:herzogenaurach ;
#     rebel:sport rebel:football ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:2000s a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2000s" ;
#     rebel:pointIntime rebel:2000 ;
#     owl:sameAs wiki:Q35024 ;
#     wiki:id "Q35024" .
#
# rebel:2004_summer_olympics a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2004 Summer Olympics" ;
#     rebel:pointIntime rebel:2004 ;
#     owl:sameAs wiki:Q8558 ;
#     wiki:id "Q8558" .
#
# rebel:2005_birmingham_tornado a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2005 Birmingham tornado" ;
#     rebel:instanceOf rebel:tornado,
#         rebel:tornadoes ;
#     rebel:location rebel:birmingham ;
#     rebel:pointIntime rebel:28_july_2005 ;
#     owl:sameAs wiki:Q4604038 ;
#     wiki:id "Q4604038" .
#
# rebel:20062007_nba_season a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2006-2007 NBA season" ;
#     rebel:sport rebel:basketball ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:2007_report a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2007 report" ;
#     rebel:mainSubject rebel:ozone_layer ;
#     rebel:pointIntime rebel:2007 ;
#     owl:sameAs wiki:Q18823313 ;
#     wiki:id "Q18823313" .
#
# rebel:2008_summer_olympics a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2008 Summer Olympics" ;
#     rebel:pointIntime rebel:2008 ;
#     owl:sameAs wiki:Q8567 ;
#     wiki:id "Q8567" .
#
# rebel:2009_rugby_world_cup a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2009 Rugby World Cup" ;
#     rebel:pointIntime rebel:2009 ;
#     owl:sameAs wiki:Q270096 ;
#     wiki:id "Q270096" .
#
# rebel:2010_commonwealth_games a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2010 Commonwealth Games" ;
#     rebel:pointIntime rebel:2010 ;
#     owl:sameAs wiki:Q695233 ;
#     wiki:id "Q695233" .
#
# rebel:2010_fifa_world_cup a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2010 FIFA World Cup" ;
#     rebel:pointIntime rebel:2010 ;
#     owl:sameAs wiki:Q176883 ;
#     wiki:id "Q176883" .
#
# rebel:2010_report a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2010 report" ;
#     rebel:pointIntime rebel:2010 ;
#     owl:sameAs wiki:Q10845221 ;
#     wiki:id "Q10845221" .
#
# <http://example.org/rebel/#2010–11_arctic_event> a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2010–11 Arctic event" ;
#     rebel:hasEffect rebel:ozone_depletion ;
#     rebel:instanceOf rebel:ozone_depletion ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:2011_asia_league_ice_hockey a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2011 Asia League Ice Hockey" ;
#     rebel:pointIntime rebel:2011 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:2011_asia_league_ice_hockey_finals a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2011 Asia League Ice Hockey finals" ;
#     rebel:pointIntime rebel:2011 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:2011_christchurch_earthquake a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2011 Christchurch earthquake" ;
#     rebel:country rebel:new_zealand ;
#     owl:sameAs wiki:Q5109109 ;
#     wiki:id "Q5109109" .
#
# rebel:2011_disasters a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2011 disasters" ;
#     rebel:pointIntime rebel:2011 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:2011_japanese_motorcycle_grand_prix a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2011 Japanese motorcycle Grand Prix" ;
#     rebel:pointIntime rebel:2011 ;
#     owl:sameAs wiki:Q845782 ;
#     wiki:id "Q845782" .
#
# rebel:2011_japanese_unified_regional_election a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2011 Japanese unified regional election" ;
#     rebel:pointIntime rebel:2011 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:2011_rugby_world_cup a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2011 Rugby World Cup" ;
#     rebel:pointIntime rebel:2011 ;
#     owl:sameAs wiki:Q270736 ;
#     wiki:id "Q270736" .
#
# rebel:2011_season a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2011 season" ;
#     rebel:pointIntime rebel:2011 ;
#     owl:sameAs wiki:Q3468113 ;
#     wiki:id "Q3468113" .
#
# rebel:2011_summer_months a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2011 summer months" ;
#     rebel:pointIntime rebel:2011 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:2011_world_artistic_gymnastics_championships a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2011 World Artistic Gymnastics Championships" ;
#     rebel:organizer rebel:international_federation_of_gymnastics ;
#     rebel:pointIntime rebel:2011 ;
#     owl:sameAs wiki:Q221504 ;
#     wiki:id "Q221504" .
#
# rebel:2011_world_figure_skating_championships a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2011 World Figure Skating Championships" ;
#     rebel:location rebel:moscow,
#         rebel:yoyogi_national_gymnasium ;
#     rebel:organizer rebel:international_skating_union ;
#     owl:sameAs wiki:Q538133 ;
#     wiki:id "Q538133" .
#
# rebel:2012_lebanon_war a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2012 Lebanon War" ;
#     rebel:pointIntime rebel:2012 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:2012_nfl_season a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2012 NFL season" ;
#     rebel:pointIntime rebel:2012 ;
#     owl:sameAs wiki:Q1395918 ;
#     wiki:id "Q1395918" .
#
# rebel:2012_olympic_games a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2012 Olympic Games" ;
#     rebel:pointIntime rebel:2012 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:2012_olympics a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2012 Olympics" ;
#     rebel:pointIntime rebel:2012 ;
#     owl:sameAs wiki:Q8577 ;
#     wiki:id "Q8577" .
#
# rebel:2012_rugby_world_cup a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2012 Rugby World Cup" ;
#     rebel:pointIntime rebel:2012 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:2012_summer_olympics a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2012 Summer Olympics" ;
#     rebel:pointIntime rebel:2012 ;
#     owl:sameAs wiki:Q8577 ;
#     wiki:id "Q8577" .
#
# rebel:2012_super_bowl a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2012 Super Bowl" ;
#     rebel:pointIntime rebel:2012 ;
#     owl:sameAs wiki:Q849079 ;
#     wiki:id "Q849079" .
#
# rebel:2012_winter_olympics a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2012 Winter Olympics" ;
#     rebel:pointIntime rebel:2012 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:2014_commonwealth_games a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2014 Commonwealth Games" ;
#     rebel:pointIntime rebel:2014 ;
#     owl:sameAs wiki:Q1116999 ;
#     wiki:id "Q1116999" .
#
# rebel:2014_indian_premier_league a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2014 Indian Premier League" ;
#     rebel:pointIntime rebel:2014 ;
#     owl:sameAs wiki:Q15711302 ;
#     wiki:id "Q15711302" .
#
# rebel:2015_european_migrant_crisis a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2015 European migrant crisis" ;
#     rebel:facetOf rebel:refugees,
#         rebel:refugees_from_ukraine ;
#     rebel:hasCause rebel:refugee,
#         rebel:refugees,
#         rebel:refugees_from_ukraine ;
#     rebel:hasPart rebel:refugees_from_ukraine ;
#     rebel:pointIntime rebel:2015 ;
#     rebel:subclassOf rebel:refugees ;
#     owl:sameAs wiki:Q20857240 ;
#     wiki:id "Q20857240" .
#
# rebel:2015_mcdonaldss_allamerican a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2015 McDonald's's All-American" ;
#     rebel:pointIntime rebel:2015 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:2015_mcdonaldss_allamerican_uniforms a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2015 McDonald's's All-American uniforms" ;
#     rebel:manufacturer rebel:mcdonalds ;
#     rebel:namedAfter rebel:mcdonalds ;
#     rebel:pointIntime rebel:2015 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:2015_season a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2015 Season" ;
#     rebel:participatingTeam rebel:royal_challengers_bangalore ;
#     rebel:pointIntime rebel:2015 ;
#     rebel:seasonOfclubOrteam rebel:royal_challengers_bangalore ;
#     rebel:winner rebel:royal_challengers_bangalore ;
#     owl:sameAs wiki:Q18208572 ;
#     wiki:id "Q18208572" .
#
# rebel:2015_study a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2015 study" ;
#     rebel:pointIntime rebel:2015 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:2016_indian_premier_league a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2016 Indian Premier League" ;
#     rebel:pointIntime rebel:2016 ;
#     owl:sameAs wiki:Q20312222 ;
#     wiki:id "Q20312222" .
#
# <http://example.org/rebel/#2016–17_season> a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2016–17 season" ;
#     rebel:sportsSeasonofLeagueorCompetition rebel:national_basketball_association ;
#     owl:sameAs wiki:Q30201458 ;
#     wiki:id "Q30201458" .
#
# <http://example.org/rebel/#2017–18> a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2017–18" ;
#     rebel:sportsSeasonofLeagueorCompetition rebel:national_hockey_league ;
#     owl:sameAs wiki:Q47015413 ;
#     wiki:id "Q47015413" .
#
# <http://example.org/rebel/#2017–18_season> a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2017–18 season" ;
#     rebel:sport rebel:ice_hockey ;
#     rebel:sportsSeasonofLeagueorCompetition rebel:national_hockey_league ;
#     owl:sameAs wiki:Q47015413 ;
#     wiki:id "Q47015413" .
#
# rebel:2018_commonwealth_games a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2018 Commonwealth Games" ;
#     rebel:pointIntime rebel:2018 ;
#     owl:sameAs wiki:Q3294383 ;
#     wiki:id "Q3294383" .
#
# rebel:2019update a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2019(update)",
#         "2019[update" ;
#     rebel:pointIntime rebel:2019 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:2020_winter_olympics a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2020 Winter Olympics" ;
#     rebel:pointIntime rebel:2020 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:202124_cycle a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2021-24 cycle" ;
#     rebel:organizer rebel:uefa ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:2022_invasion a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2022 invasion" ;
#     rebel:country rebel:portugal,
#         rebel:portuguese ;
#     rebel:location rebel:portugal,
#         rebel:portuguese ;
#     rebel:participant rebel:portuguese ;
#     rebel:pointIntime rebel:2022 ;
#     rebel:startTime rebel:2022 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:2022_wmounep_scientific_assessment_of_ozone_depletion a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2022 WMO/UNEP Scientific Assessment of Ozone Depletion" ;
#     rebel:pointIntime rebel:2022 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:2022_world_cup a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2022 World Cup" ;
#     rebel:pointIntime rebel:2022 ;
#     owl:sameAs wiki:Q284163 ;
#     wiki:id "Q284163" .
#
# rebel:2022_world_cup_ball a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2022 World Cup ball" ;
#     rebel:manufacturer rebel:adidas ;
#     rebel:pointIntime rebel:2022 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# <http://example.org/rebel/#2022–2023_irish_antiimmigration_protests> a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2022–2023 Irish anti-immigration protests" ;
#     rebel:country rebel:ireland ;
#     rebel:location rebel:ireland ;
#     rebel:pointIntime rebel:2022,
#         rebel:november_2022 ;
#     rebel:startTime rebel:2022,
#         rebel:november_2022 ;
#     owl:sameAs wiki:Q115824494 ;
#     wiki:id "Q115824494" .
#
# rebel:202324_season a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "2023-24 season" ;
#     rebel:sportsSeasonofLeagueorCompetition rebel:national_hockey_league ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:20613_chibaken a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "20613 Chibaken" ;
#     rebel:siteOfastronomicalDiscovery rebel:lowell_observatory ;
#     owl:sameAs wiki:Q3598064 ;
#     wiki:id "Q3598064" .
#
# rebel:20km_evacuation_zone a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "20-km evacuation zone" ;
#     rebel:locatedIntheAdministrativeterritorialEntity rebel:fukushima_prefecture ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:21966_hamadori a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "21966 Hamadori" ;
#     rebel:siteOfastronomicalDiscovery rebel:lowell_observatory ;
#     owl:sameAs wiki:Q3598101 ;
#     wiki:id "Q3598101" .
#
# rebel:22719_nakadori a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "22719 Nakadori" ;
#     rebel:siteOfastronomicalDiscovery rebel:lowell_observatory ;
#     owl:sameAs wiki:Q3598137 ;
#     wiki:id "Q3598137" .
#
# rebel:22745_rikuzentakata a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "22745 Rikuzentakata" ;
#     rebel:siteOfastronomicalDiscovery rebel:lowell_observatory ;
#     owl:sameAs wiki:Q3598138 ;
#     wiki:id "Q3598138" .
#
# rebel:22914_tsunanmachi a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "22914 Tsunanmachi" ;
#     rebel:siteOfastronomicalDiscovery rebel:lowell_observatory ;
#     owl:sameAs wiki:Q3598144 ;
#     wiki:id "Q3598144" .
#
# rebel:34p a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "34p" ;
#     rebel:instanceOf rebel:price_tag ;
#     rebel:subclassOf rebel:price_tag ;
#     owl:sameAs wiki:Q18844549 ;
#     wiki:id "Q18844549" .
#
# rebel:644_companies_in_japan a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "644 companies in Japan" ;
#     rebel:country rebel:japan ;
#     rebel:endTime rebel:march_2012 ;
#     rebel:pointIntime rebel:march_2012 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:a_1976_report a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "a 1976 report" ;
#     rebel:publisher rebel:united_states_national_academy_of_sciences ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:a_big_earthquake a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "a big earthquake" ;
#     rebel:country rebel:new_zealand ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:a_camp_for_syrian_kurds a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "A camp for Syrian Kurds",
#         "a camp for Syrian Kurds" ;
#     rebel:locatedIntheAdministrativeterritorialEntity rebel:moqebleh ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:a_fierce_and_bitter_business_rivalry a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "a fierce and bitter business rivalry" ;
#     rebel:participant rebel:adidas,
#         rebel:puma_se ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:a_gasworks a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "a gasworks" ;
#     rebel:inception rebel:1861 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:a_gasworks_and_street_lighting a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "a gasworks and street lighting" ;
#     rebel:inception rebel:1861 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:a_line_of_soviet_themed_items a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "a line of Soviet themed items" ;
#     rebel:manufacturer rebel:adidas ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:a_long_history_of_bigotry_towards_slavs a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "a long history of bigotry towards Slavs" ;
#     rebel:country rebel:ukraine ;
#     rebel:facetOf rebel:slavs ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:a_mark_mackinnon a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "A Mark MacKinnon" ;
#     rebel:employer rebel:the_globe_and_mail ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:a_panel_of_expertss_seven_principles_for_the_reconstruction_framework a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "a panel of experts's Seven Principles for the Reconstruction Framework" ;
#     rebel:publicationDate rebel:10_may_2011 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:a_possible_russian_attack_on_ukraine a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "a possible Russian attack on Ukraine" ;
#     rebel:country rebel:poland ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:a_rare_hole a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "a rare hole" ;
#     rebel:instanceOf rebel:ozone_hole ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:a_second_tornado a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "a second tornado" ;
#     rebel:instanceOf rebel:thunderstorm ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:a_study a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "a study" ;
#     rebel:mainSubject rebel:skin_cancer ;
#     rebel:publicationDate rebel:1986 ;
#     rebel:publishedIn rebel:nature ;
#     owl:sameAs wiki:Q20442538 ;
#     wiki:id "Q20442538" .
#
# rebel:a_study_in_1986 a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "a study in 1986" ;
#     rebel:pointIntime rebel:1986 ;
#     rebel:publicationDate rebel:1986 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:a_study_in_1986_claiming_that_an_additional_40_million_cases_and_800000_cancer_deaths_were_to_be_expected_in_the_us_in_the_next_88_years a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "a study in 1986 claiming that an additional 40 million cases and 800,000 cancer deaths were to be expected in the U.S. in the next 88 years" ;
#     rebel:pointIntime rebel:1986 ;
#     rebel:publicationDate rebel:1986 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:a_study_was_published_in_the_journal_nature a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "a study was published in the journal Nature" ;
#     rebel:publicationDate rebel:october_2_2011 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:a_synthetic_process_for_indigo_dye a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "a synthetic process for indigo dye" ;
#     rebel:inception rebel:1897 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:a_zoo_in_zaporizhzhia a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "a zoo in Zaporizhzhia" ;
#     rebel:country rebel:ukraine ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:aahlloyds a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "AAH/Lloyds" ;
#     rebel:country rebel:uk ;
#     rebel:industry rebel:distribution,
#         rebel:pharmaceutical_distribution,
#         rebel:pharmaceutical_distribution_industry ;
#     rebel:parentOrganization rebel:phoenix_group ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:absorption a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "absorption" ;
#     rebel:subclassOf rebel:light ;
#     owl:sameAs wiki:Q332828 ;
#     wiki:id "Q332828" .
#
# rebel:abstain_from_condemning_russia a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "abstain from condemning Russia" ;
#     rebel:participant rebel:un ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:acclimatize a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "acclimatize" ;
#     rebel:facetOf rebel:radiation,
#         rebel:uv_radiation ;
#     rebel:subclassOf rebel:radiation ;
#     owl:sameAs wiki:Q42475560 ;
#     wiki:id "Q42475560" .
#
# rebel:accountancy a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "accountancy" ;
#     rebel:facetOf rebel:tax ;
#     rebel:fieldOfthisOccupation rebel:tax ;
#     rebel:instanceOf rebel:professional,
#         rebel:professions ;
#     rebel:partOf rebel:tax ;
#     rebel:studies rebel:tax ;
#     rebel:subclassOf rebel:professional,
#         rebel:tax ;
#     owl:sameAs wiki:Q4116214 ;
#     wiki:id "Q4116214" .
#
# rebel:acf_holding_nv a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "ACF Holding NV" ;
#     rebel:headquartersLocation rebel:maarssen ;
#     rebel:locationOfformation rebel:maarssen ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:adidas_brazuca a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Adidas Brazuca" ;
#     rebel:manufacturer rebel:adidas ;
#     rebel:pointIntime rebel:2014 ;
#     owl:sameAs wiki:Q903284 ;
#     wiki:id "Q903284" .
#
# rebel:adidas_brazuca_for_the_2014_world_cup a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Adidas Brazuca for the 2014 World Cup" ;
#     rebel:pointIntime rebel:2014 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:adidas_by_stella_mccartney a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Adidas by Stella McCartney" ;
#     rebel:foundedBy rebel:stella_mccartney ;
#     rebel:namedAfter rebel:stella_mccartney ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:adidas_confirmed a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Adidas Confirmed" ;
#     rebel:developer rebel:adidas ;
#     rebel:inception rebel:24_march_2015 ;
#     rebel:manufacturer rebel:adidas ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:adidas_confirmed_app a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Adidas Confirmed app" ;
#     rebel:developer rebel:adidas ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:adidas_eqt_support_9317 a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Adidas EQT Support 93/17" ;
#     rebel:inception rebel:26_january_2017 ;
#     rebel:manufacturer rebel:adidas ;
#     rebel:partOftheSeries rebel:adidas_eqt ;
#     rebel:publicationDate rebel:26_january_2017 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:adidas_futurecraft a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Adidas Futurecraft" ;
#     rebel:hasPart rebel:biosteel ;
#     rebel:productOrmaterialProduced rebel:biosteel ;
#     rebel:uses rebel:biosteel ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:adidas_futurecraft_biofabric a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Adidas Futurecraft Biofabric" ;
#     rebel:hasPart rebel:biosteel ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:adidas_gtx_prot a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Adidas GTX Pro-T" ;
#     rebel:manufacturer rebel:adidas ;
#     rebel:sport rebel:tennis ;
#     rebel:subclassOf rebel:tennis_racquet ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:adidas_gtxpro a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Adidas GTX-Pro" ;
#     rebel:manufacturer rebel:adidas ;
#     rebel:sport rebel:tennis ;
#     rebel:subclassOf rebel:tennis_racquet ;
#     rebel:usedBy rebel:ivan_lendl ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:adidas_gymnastics_leotards a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Adidas gymnastics leotards" ;
#     rebel:inception rebel:2006 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:adidas_has_been_criticized_for_operating_sweatshops a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Adidas has been criticized for operating sweatshops" ;
#     rebel:country rebel:indonesia ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:adidas_is_all_in a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Adidas is all in" ;
#     rebel:inception rebel:2011 ;
#     rebel:instanceOf rebel:slogan ;
#     rebel:manufacturer rebel:adidas ;
#     rebel:ownedBy rebel:adidas ;
#     rebel:pointIntime rebel:2011 ;
#     rebel:publicationDate rebel:2011 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:adidas_major_league_baseball_hardgoods a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Adidas Major League Baseball hardgoods" ;
#     rebel:manufacturer rebel:dicks_sporting_goods ;
#     rebel:ownedBy rebel:dicks_sporting_goods ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:adidas_masterblaster_elite a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Adidas MasterBlaster Elite" ;
#     rebel:inception rebel:2008 ;
#     rebel:instanceOf rebel:cricket_bat ;
#     rebel:subclassOf rebel:cricket_bat ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:adidas_national_lacrosse_classic a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Adidas National Lacrosse Classic" ;
#     rebel:sport rebel:lacrosse ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:adidas_predator a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Adidas Predator" ;
#     rebel:manufacturer rebel:adidas ;
#     owl:sameAs wiki:Q420789 ;
#     wiki:id "Q420789" .
#
# rebel:adidas_replica_all_blacks_jersey a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Adidas replica All Blacks jersey" ;
#     rebel:country rebel:new_zealand ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:adidas_skateboarding a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Adidas Skateboarding" ;
#     rebel:industry rebel:skateboarding ;
#     rebel:productOrmaterialProduced rebel:shoe,
#         rebel:shoes,
#         rebel:shoes_made_specifically_for_skateboarding,
#         rebel:skateboarding ;
#     rebel:sport rebel:skateboarding ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:adidas_telstar a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Adidas Telstar" ;
#     rebel:inception rebel:1970 ;
#     rebel:sport rebel:football ;
#     owl:sameAs wiki:Q644994 ;
#     wiki:id "Q644994" .
#
# rebel:adidass_replica_all_blacks_jersey a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Adidas's replica All Blacks jersey" ;
#     rebel:country rebel:new_zealand ;
#     rebel:countryOforigin rebel:new_zealand ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:adidassalomon a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Adidas-Salomon" ;
#     rebel:inception rebel:1997 ;
#     owl:sameAs wiki:Q17875093 ;
#     wiki:id "Q17875093" .
#
# rebel:adilette_sandals a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Adilette sandals" ;
#     rebel:instanceOf rebel:sandals ;
#     rebel:productOrmaterialProduced rebel:sandals ;
#     rebel:subclassOf rebel:sandals ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:adipure a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "adiPure" ;
#     rebel:manufacturer rebel:adidas ;
#     owl:sameAs wiki:Q4682574 ;
#     wiki:id "Q4682574" .
#
# rebel:adissage a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Adissage" ;
#     rebel:instanceOf rebel:footache,
#         rebel:footaches ;
#     rebel:productOrmaterialProduced rebel:footache,
#         rebel:footaches ;
#     rebel:subclassOf rebel:footache,
#         rebel:footaches ;
#     rebel:use rebel:footache,
#         rebel:footaches ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:adolf_dasslers_wife a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Adolf Dassler's wife" ;
#     rebel:conflict rebel:world_war_ii ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:aerosol_cans a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "aerosol cans" ;
#     rebel:hasPart rebel:aerosol_spray ;
#     rebel:use rebel:aerosol_spray ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:affiliation a rebel:Relation,
#         rdf:Property ;
#     rdfs:label "affiliation" ;
#     owl:sameAs wiki:P1416 ;
#     wiki:id "P1416" ;
#     wiki:type wiki:Property .
#
# rebel:afghan a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Afghan" ;
#     rebel:continent rebel:europe ;
#     rebel:inception rebel:1980 ;
#     rebel:subclassOf rebel:immigrants ;
#     owl:sameAs wiki:Q383029 ;
#     wiki:id "Q383029" .
#
# rebel:aftermath_of_the_2011_tōhoku_earthquake_and_tsunami a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "aftermath of the 2011 Tōhoku earthquake and tsunami" ;
#     rebel:country rebel:japan ;
#     rebel:facetOf rebel:2011_tōhoku_earthquake_and_tsunami ;
#     rebel:instanceOf rebel:humanitarian_crisis ;
#     rebel:location rebel:tōhoku_region,
#         rebel:tōhoku_region_of_japan ;
#     owl:sameAs wiki:Q1136168 ;
#     wiki:id "Q1136168" .
#
# rebel:air_travel_was_not_available_in_ukraine a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Air travel was not available in Ukraine" ;
#     rebel:country rebel:ukraine ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:akashi a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Akashi" ;
#     rebel:locatedIntheAdministrativeterritorialEntity rebel:hyōgo ;
#     owl:sameAs wiki:Q26406 ;
#     wiki:id "Q26406" .
#
# rebel:al_rihla a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Al Rihla" ;
#     rebel:manufacturer rebel:adidas ;
#     owl:sameAs wiki:Q111432258 ;
#     wiki:id "Q111432258" .
#
# rebel:alizarin a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "alizarin" ;
#     rebel:instanceOf rebel:pigment ;
#     rebel:subjectHasrole rebel:pigment ;
#     owl:sameAs wiki:Q267813 ;
#     wiki:id "Q267813" .
#
# rebel:all_blacks_fans a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "All Blacks fans" ;
#     rebel:country rebel:new_zealand ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:all_blacks_jerseys a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "All Blacks Jerseys" ;
#     rebel:seasonOfclubOrteam rebel:all_blacks ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:allied_bombers a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Allied bombers" ;
#     rebel:subclassOf rebel:air_raids ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:allotropes a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "allotropes" ;
#     rebel:hasPart rebel:oxygen ;
#     rebel:subclassOf rebel:oxygen ;
#     owl:sameAs wiki:Q622460 ;
#     wiki:id "Q622460" .
#
# rebel:amazon a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Amazon" ;
#     rebel:industry rebel:ecommerce ;
#     rebel:productOrmaterialProduced rebel:ecommerce ;
#     owl:sameAs wiki:Q3884 ;
#     wiki:id "Q3884" .
#
# rebel:american_midwest a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "American Midwest" ;
#     rebel:hasPart rebel:california ;
#     rebel:locatedIntheAdministrativeterritorialEntity rebel:california ;
#     owl:sameAs wiki:Q4744435 ;
#     wiki:id "Q4744435" .
#
# rebel:american_red_cross a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "American Red Cross" ;
#     rebel:country rebel:us ;
#     owl:sameAs wiki:Q470110 ;
#     wiki:id "Q470110" .
#
# rebel:amflora a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Amflora" ;
#     rebel:manufacturer rebel:basf_plant_science ;
#     owl:sameAs wiki:Q239942 ;
#     wiki:id "Q239942" .
#
# rebel:amflora_and_starch_potato a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Amflora and Starch Potato" ;
#     rebel:instanceOf rebel:genetically_modified_potato ;
#     rebel:manufacturer rebel:basf_plant_science ;
#     rebel:ownedBy rebel:basf_plant_science ;
#     rebel:parentOrganization rebel:basf_plant_science ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:ammonia_factories a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "ammonia factories" ;
#     rebel:headquartersLocation rebel:ludwigshafen ;
#     rebel:locatedIntheAdministrativeterritorialEntity rebel:ludwigshafen ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:an_explosion_occurred a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "an explosion occurred" ;
#     rebel:locatedIntheAdministrativeterritorialEntity rebel:ludwigshafen ;
#     rebel:location rebel:ludwigshafen ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:an_extraordinary_members_meeting a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "An extraordinary members meeting",
#         "an extraordinary members meeting" ;
#     rebel:pointIntime rebel:18_february_2005 ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:andrew_lawson a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Andrew Lawson" ;
#     rebel:educatedAt rebel:university_of_california_berkeley ;
#     rebel:employer rebel:university_of_california_berkeley ;
#     owl:sameAs wiki:Q504233 ;
#     wiki:id "Q504233" .
#
# rebel:andriy_demchenko a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Andriy Demchenko" ;
#     rebel:employer rebel:ukrainian_border_guard ;
#     owl:sameAs wiki:Q2040497 ;
#     wiki:id "Q2040497" .
#
# rebel:andy_murray a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Andy Murray" ;
#     rebel:ranking rebel:1,
#         rebel:3,
#         rebel:4,
#         rebel:6,
#         rebel:world_number_4 ;
#     rebel:sport rebel:tennis,
#         rebel:tennis_player ;
#     owl:sameAs wiki:Q10125 ;
#     wiki:id "Q10125" .
#
# rebel:angela_merkels_opendoor_policy a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Angela Merkel's Open-Door Policy" ;
#     rebel:namedAfter rebel:angela_merkel ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:aniline_extracted_from_coal_tar a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "aniline extracted from coal tar" ;
#     rebel:discovererOrinventor rebel:william_henry_perkin ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:anne_m_burford a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Anne M. Burford" ;
#     rebel:positionHeld rebel:administrator_of_the_united_states_environmental_protection_agency ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:annex_vi a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Annex VI" ;
#     rebel:partOf rebel:marpol ;
#     owl:sameAs wiki:Q116690609 ;
#     wiki:id "Q116690609" .
#
# rebel:annexation_of_crimea a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "annexation of Crimea" ;
#     rebel:participant rebel:russian_federation ;
#     owl:sameAs wiki:Q15920546 ;
#     wiki:id "Q15920546" .
#
# rebel:annotext a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "AnNoText" ;
#     rebel:industry rebel:software_for_lawyers ;
#     rebel:instanceOf rebel:software_for_lawyers ;
#     owl:sameAs wiki:Q482361 ;
#     wiki:id "Q482361" .
#
# rebel:antarctic_total_column_ozone a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Antarctic total column ozone" ;
#     rebel:subclassOf rebel:ozone ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:antinuclear_demonstration_of_50000_people a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "anti-nuclear demonstration of 50,000 people" ;
#     rebel:locatedIntheAdministrativeterritorialEntity rebel:stuttgart ;
#     rebel:location rebel:stuttgart ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:antinuclear_demonstration_of_50000_people_in_stuttgart a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "anti-nuclear demonstration of 50,000 people in Stuttgart" ;
#     rebel:facetOf rebel:fukushima_incident ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:antirabies a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "anti-rabies" ;
#     rebel:subclassOf rebel:vaccination,
#         rebel:vaccinations,
#         rebel:vaccine ;
#     owl:sameAs wiki:Q76583032 ;
#     wiki:id "Q76583032" .
#
# rebel:antirabies_vaccination a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "anti-rabies vaccination" ;
#     rebel:subclassOf rebel:preventative_health_measures ;
#     owl:sameAs wiki:Q45720040 ;
#     wiki:id "Q45720040" .
#
# rebel:antirabies_vaccine a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "anti-rabies vaccine" ;
#     rebel:subclassOf rebel:preventative_health_measures ;
#     owl:sameAs wiki:Q76583032 ;
#     wiki:id "Q76583032" .
#
# rebel:antitank_weapon a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "anti-tank weapon" ;
#     rebel:serviceEntry rebel:1943 ;
#     owl:sameAs wiki:Q10912680 ;
#     wiki:id "Q10912680" .
#
# rebel:antwerp a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Antwerp" ;
#     rebel:country rebel:belgium ;
#     owl:sameAs wiki:Q12892 ;
#     wiki:id "Q12892" .
#
# rebel:applied_for_asylum a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "applied for asylum" ;
#     rebel:country rebel:iceland ;
#     rebel:facetOf rebel:refugees ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:appliesTojurisdiction a rebel:Relation,
#         rdf:Property ;
#     rdfs:label "applies to jurisdiction" ;
#     owl:sameAs wiki:P1001 ;
#     wiki:id "P1001" ;
#     wiki:type wiki:Property .
#
# rebel:appointedBy a rebel:Relation,
#         rdf:Property ;
#     rdfs:label "appointed by" ;
#     owl:sameAs wiki:P748 ;
#     wiki:id "P748" ;
#     wiki:type wiki:Property .
#
# rebel:architect a rebel:Relation,
#         rdf:Property ;
#     rdfs:label "architect" ;
#     owl:sameAs wiki:P84 ;
#     wiki:id "P84" ;
#     wiki:type wiki:Property .
#
# rebel:arctic_total_column_ozone a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Arctic total column ozone" ;
#     rebel:subclassOf rebel:ozone ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:area a rebel:Relation,
#         rdf:Property ;
#     rdfs:label "area" ;
#     owl:sameAs wiki:P518 ;
#     wiki:id "P518" ;
#     wiki:type wiki:Property .
#
# rebel:argentine_governments a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Argentine government's" ;
#     rebel:headquartersLocation rebel:buenos_aires ;
#     rebel:locatedIntheAdministrativeterritorialEntity rebel:buenos_aires ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:as_a_service a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "As a service",
#         "as a service" ;
#     rebel:subclassOf rebel:software ;
#     owl:sameAs wiki:Q25036597 ;
#     wiki:id "Q25036597" .
#
# rebel:assembly_point a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Assembly point" ;
#     rebel:country rebel:poland ;
#     owl:sameAs wiki:Q18690969 ;
#     wiki:id "Q18690969" .
#
# rebel:assembly_point_for_refugees a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Assembly point for refugees" ;
#     rebel:appliesTojurisdiction rebel:poland ;
#     rebel:country rebel:poland ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:assembly_points a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Assembly points" ;
#     rebel:country rebel:poland ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:assembly_points_for_refugees a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Assembly points for refugees" ;
#     rebel:appliesTojurisdiction rebel:poland ;
#     rebel:country rebel:poland ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:association_agreement a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Association Agreement" ;
#     rebel:appliesTojurisdiction rebel:european_union ;
#     rebel:country rebel:european_union ;
#     rebel:participant rebel:european_union ;
#     owl:sameAs wiki:Q745126 ;
#     wiki:id "Q745126" .
#
# rebel:association_agreement_with_the_european_union a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Association Agreement with the European Union" ;
#     rebel:appliesTojurisdiction rebel:schengen_area ;
#     rebel:partOf rebel:schengen_area ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:asteroids_comets_meteors_2012 a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Asteroids, Comets, Meteors 2012" ;
#     rebel:location rebel:toki_messe ;
#     rebel:organizer rebel:international_astronomical_union ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:asteroids_comets_meteors_2012_conference a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Asteroids, Comets, Meteors 2012 conference" ;
#     rebel:location rebel:toki_messe ;
#     rebel:organizer rebel:international_astronomical_union ;
#     owl:sameAs wiki:no-wikiID ;
#     wiki:id "no-wikiID" .
#
# rebel:asthma a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "asthma" ;
#     rebel:drugUsedforTreatment rebel:inhalers ;
#     rebel:subclassOf rebel:respiratory_difficulties,
#         rebel:respiratory_problem ;
#     owl:sameAs wiki:Q35869 ;
#     wiki:id "Q35869" .
#
# rebel:asthma_inhalers a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "asthma inhalers" ;
#     rebel:hasPart rebel:cfcs ;
#     owl:sameAs wiki:Q86705281 ;
#     wiki:id "Q86705281" .
#
# rebel:asv_herzogenaurach a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "ASV Herzogenaurach" ;
#     rebel:headquartersLocation rebel:herzogenaurach ;
#     rebel:locatedIntheAdministrativeterritorialEntity rebel:herzogenaurach ;
#     rebel:sport rebel:football ;
#     owl:sameAs wiki:Q298129 ;
#     wiki:id "Q298129" .
#
# ...
#         rebel:international_organizations,
#         rebel:national_academy_of_sciences,
#         rebel:united_states_national_academy_of_sciences ;
#     rebel:officeHeldbyHeadofGovernment rebel:us_president ;
#     rebel:sharesBorderwith rebel:japan,
#         rebel:mexico,
#         rebel:ukraine ;
#     owl:sameAs wiki:Q30,
#         wiki:Q638645 ;
#     wiki:id "Q30",
#         "Q638645" .
#
# wiki:Q30 wiki:P102 wiki:Q270794,
#         wiki:Q52847,
#         wiki:Q58250794 ;
#     wiki:P1313 wiki:Q11696 ;
#     wiki:P1412 wiki:Q1860 ;
#     wiki:P150 wiki:Q1581,
#         wiki:Q61,
#         wiki:Q782 ;
#     wiki:P172 wiki:Q59574471 ;
#     wiki:P194 wiki:Q11701 ;
#     wiki:P279 wiki:Q131572 ;
#     wiki:P31 wiki:Q131572 ;
#     wiki:P36 wiki:Q61 ;
#     wiki:P47 wiki:Q17,
#         wiki:Q212,
#         wiki:Q96 ;
#     wiki:P530 wiki:Q17,
#         wiki:Q212,
#         wiki:Q8798 .
#
# rebel:ozone a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Ozone",
#         "ozone" ;
#     rebel:differentFrom rebel:ozone_hole,
#         rebel:uva ;
#     rebel:facetOf rebel:montreal_protocol,
#         rebel:ozone,
#         rebel:ozone_depletion ;
#     rebel:hasCause rebel:cfc,
#         rebel:cfc_photolysis,
#         rebel:nitrous_oxide,
#         rebel:ozone_depletion,
#         rebel:ozone_hole,
#         rebel:uv,
#         rebel:uv_radiation ;
#     rebel:hasEffect rebel:ozone_depletion,
#         rebel:ozone_hole,
#         rebel:skin_cancer,
#         rebel:uv,
#         rebel:uv_radiation,
#         rebel:uva ;
#     rebel:hasPart rebel:atomic_oxygen_radicals,
#         rebel:br,
#         rebel:bromine,
#         rebel:cfc,
#         rebel:chlorine,
#         rebel:chlorine_compound,
#         rebel:chlorine_compounds,
#         rebel:cl,
#         rebel:halogen,
#         rebel:halogen_group,
#         rebel:methyl_bromide,
#         rebel:nitrous_oxide,
#         rebel:no2,
#         rebel:o2,
#         rebel:oxidant,
#         rebel:oxygen,
#         rebel:oxygen_o2,
#         rebel:oxygen_radicals,
#         rebel:ozone,
#         rebel:ozone_hole,
#         rebel:ozone_molecule,
#         rebel:thinning_layer,
#         rebel:ultraviolet,
#         rebel:uva ;
#     rebel:hasPartsofTheclass rebel:cfc,
#         rebel:chlorine,
#         rebel:oxidant,
#         rebel:oxygen ;
#     rebel:instanceOf rebel:atmospheric_gas,
#         rebel:cfc,
#         rebel:oxidant,
#         rebel:photochemical ;
#     rebel:namedAfter rebel:ozone_hole ;
#     rebel:partOf rebel:earths_atmosphere,
#         rebel:earths_surface,
#         rebel:ozone,
#         rebel:ozone_hole,
#         rebel:ozone_layer,
#         rebel:stratosphere,
#         rebel:stratospheric,
#         rebel:stratospheric_ozone,
#         rebel:thinning_layer,
#         rebel:total_column ;
#     rebel:subclassOf rebel:atmospheric_gas,
#         rebel:cfc,
#         rebel:manmade_chemicals,
#         rebel:molecule,
#         rebel:oxidant,
#         rebel:ozone ;
#     rebel:subjectHasrole rebel:oxidant ;
#     owl:sameAs wiki:Q36933 ;
#     wiki:id "Q36933" .
#
# wiki:Q183 wiki:P102 wiki:Q1151241,
#         wiki:Q23681360,
#         wiki:Q458,
#         wiki:Q8752 ;
#     wiki:P1313 wiki:Q212071 ;
#     wiki:P150 wiki:Q1055,
#         wiki:Q64,
#         wiki:Q980,
#         wiki:Q985 ;
#     wiki:P1830 wiki:Q9322 ;
#     wiki:P30 wiki:Q46 ;
#     wiki:P36 wiki:Q64 ;
#     wiki:P361 wiki:Q46 ;
#     wiki:P47 wiki:Q217,
#         wiki:Q40,
#         wiki:Q8798 ;
#     wiki:P530 wiki:Q217,
#         wiki:Q664 ;
#     wiki:P6 wiki:Q567 .
#
# rebel:germany a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Germany" ;
#     rebel:capital rebel:berlin ;
#     rebel:containsAdministrativeterritorialEntity rebel:badenwürttemberg,
#         rebel:bavaria,
#         rebel:berlin,
#         rebel:hamburg ;
#     rebel:continent rebel:europe ;
#     rebel:diplomaticRelation rebel:moldova,
#         rebel:new_zealand ;
#     rebel:headOfgovernment rebel:angela_merkel ;
#     rebel:memberOf rebel:allied,
#         rebel:dach,
#         rebel:eu,
#         rebel:european_union ;
#     rebel:officeHeldbyHeadofGovernment rebel:chancellor ;
#     rebel:ownerOf rebel:deutsche_bahn ;
#     rebel:partOf rebel:europe ;
#     rebel:sharesBorderwith rebel:austria,
#         rebel:moldova,
#         rebel:ukrainian ;
#     owl:sameAs wiki:Q183 ;
#     wiki:id "Q183" .
#
# wiki:Q212 wiki:P102 wiki:Q1065,
#         wiki:Q1065854,
#         wiki:Q1969730,
#         wiki:Q8752 ;
#     wiki:P1269 wiki:Q381148 ;
#     wiki:P131 wiki:Q212 ;
#     wiki:P1313 wiki:Q30461,
#         wiki:Q579677 ;
#     wiki:P150 wiki:Q157835,
#         wiki:Q1781,
#         wiki:Q1899,
#         wiki:Q43070,
#         wiki:Q605714 ;
#     wiki:P17 wiki:Q212 ;
#     wiki:P172 wiki:Q24089934,
#         wiki:Q41,
#         wiki:Q44806,
#         wiki:Q49542,
#         wiki:Q5,
#         wiki:Q7878531,
#         wiki:Q8060,
#         wiki:Q8798 ;
#     wiki:P30 wiki:Q46 ;
#     wiki:P31 wiki:Q7275 ;
#     wiki:P36 wiki:Q36036 ;
#     wiki:P361 wiki:Q46,
#         wiki:Q900636 ;
#     wiki:P47 wiki:Q159,
#         wiki:Q17,
#         wiki:Q184,
#         wiki:Q188,
#         wiki:Q189,
#         wiki:Q191,
#         wiki:Q211,
#         wiki:Q213,
#         wiki:Q214,
#         wiki:Q217,
#         wiki:Q219,
#         wiki:Q28,
#         wiki:Q30,
#         wiki:Q34,
#         wiki:Q36,
#         wiki:Q39,
#         wiki:Q43,
#         wiki:Q49542,
#         wiki:Q55,
#         wiki:Q664,
#         wiki:Q7737,
#         wiki:Q801,
#         wiki:Q809,
#         wiki:Q8752,
#         wiki:Q9035 ;
#     wiki:P530 wiki:Q142,
#         wiki:Q145,
#         wiki:Q150,
#         wiki:Q159,
#         wiki:Q16,
#         wiki:Q189,
#         wiki:Q213,
#         wiki:Q217,
#         wiki:Q219,
#         wiki:Q30,
#         wiki:Q458,
#         wiki:Q55,
#         wiki:Q664,
#         wiki:Q8752 ;
#     wiki:P793 wiki:Q59574471 .
#
# wiki:Q17 wiki:P102 wiki:Q23681360 ;
#     wiki:P150 wiki:Q1194394,
#         wiki:Q1206018,
#         wiki:Q123258,
#         wiki:Q129465,
#         wiki:Q146790,
#         wiki:Q1490,
#         wiki:Q161176,
#         wiki:Q16877250,
#         wiki:Q17139,
#         wiki:Q205526,
#         wiki:Q2356082,
#         wiki:Q26600,
#         wiki:Q328615,
#         wiki:Q44843,
#         wiki:Q47896,
#         wiki:Q568015,
#         wiki:Q71707 ;
#     wiki:P1830 wiki:Q3024789 ;
#     wiki:P47 wiki:Q212,
#         wiki:Q30 ;
#     wiki:P530 wiki:Q106856325,
#         wiki:Q30,
#         wiki:Q40,
#         wiki:Q8752 ;
#     wiki:P793 wiki:Q214866,
#         wiki:Q34661037,
#         wiki:Q362,
#         wiki:Q4353258,
#         wiki:Q7944,
#         wiki:Q8070 .
#
# wiki:Q3895 wiki:P1056 wiki:Q1070940,
#         wiki:Q11460,
#         wiki:Q1381731,
#         wiki:Q14552454,
#         wiki:Q1545022,
#         wiki:Q161928,
#         wiki:Q167270,
#         wiki:Q1886349,
#         wiki:Q190868,
#         wiki:Q202833,
#         wiki:Q217541,
#         wiki:Q223269,
#         wiki:Q22676,
#         wiki:Q2736,
#         wiki:Q28188413,
#         wiki:Q28298486,
#         wiki:Q41583,
#         wiki:Q5372,
#         wiki:Q608441,
#         wiki:Q645292,
#         wiki:Q660782,
#         wiki:Q815554,
#         wiki:Q877423 ;
#     wiki:P112 wiki:Q1156557,
#         wiki:Q36964457,
#         wiki:Q4457,
#         wiki:Q76751 ;
#     wiki:P127 wiki:Q1156557,
#         wiki:Q232812,
#         wiki:Q3895,
#         wiki:Q779722 ;
#     wiki:P1344 wiki:Q1278259,
#         wiki:Q8438 ;
#     wiki:P1365 wiki:Q466183 ;
#     wiki:P138 wiki:Q4457 ;
#     wiki:P155 wiki:Q35255 ;
#     wiki:P159 wiki:Q1615401,
#         wiki:Q84 ;
#     wiki:P17 wiki:Q159,
#         wiki:Q17,
#         wiki:Q183,
#         wiki:Q211201,
#         wiki:Q252,
#         wiki:Q408,
#         wiki:Q664,
#         wiki:Q668,
#         wiki:Q842438 ;
#     wiki:P1830 wiki:Q1143000,
#         wiki:Q1278259,
#         wiki:Q155223,
#         wiki:Q157064,
#         wiki:Q15789,
#         wiki:Q1788081,
#         wiki:Q18543,
#         wiki:Q2120822,
#         wiki:Q213417,
#         wiki:Q21468507,
#         wiki:Q28298486,
#         wiki:Q35255,
#         wiki:Q357048,
#         wiki:Q466183,
#         wiki:Q4682708,
#         wiki:Q55801,
#         wiki:Q7380124,
#         wiki:Q7798009,
#         wiki:Q877423 ;
#     wiki:P2541 wiki:Q1070940 ;
#     wiki:P31 wiki:Q167270,
#         wiki:Q219577 ;
#     wiki:P355 wiki:Q1143000,
#         wiki:Q1156557,
#         wiki:Q157064,
#         wiki:Q15789,
#         wiki:Q2120822,
#         wiki:Q466183,
#         wiki:Q7380124 ;
#     wiki:P452 wiki:Q39809,
#         wiki:Q4916,
#         wiki:Q850210 ;
#     wiki:P461 wiki:Q35255 ;
#     wiki:P488 wiki:Q71147 ;
#     wiki:P495 wiki:Q211201 ;
#     wiki:P571 wiki:Q2065,
#         wiki:Q2648,
#         wiki:Q5188,
#         wiki:Q69279026 ;
#     wiki:P641 wiki:Q10962,
#         wiki:Q148636,
#         wiki:Q2736,
#         wiki:Q41466,
#         wiki:Q5369,
#         wiki:Q5375,
#         wiki:Q5377,
#         wiki:Q847 ;
#     wiki:P740 wiki:Q252,
#         wiki:Q84 ;
#     wiki:P749 wiki:Q1156557,
#         wiki:Q3895,
#         wiki:Q779722 .
#
# rebel:ukraine a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Ukraine" ;
#     rebel:capital rebel:lviv ;
#     rebel:containsAdministrativeterritorialEntity rebel:budapest,
#         rebel:donbas,
#         rebel:donetsk,
#         rebel:kiev,
#         rebel:zaporizhzhia ;
#     rebel:continent rebel:europe,
#         rebel:european ;
#     rebel:country rebel:ukraine ;
#     rebel:diplomaticRelation rebel:bulgaria,
#         rebel:canada,
#         rebel:czech_republic,
#         rebel:eu,
#         rebel:european_union,
#         rebel:france,
#         rebel:french,
#         rebel:iceland,
#         rebel:moldova,
#         rebel:netherlands,
#         rebel:new_zealand,
#         rebel:russia,
#         rebel:russian_federation,
#         rebel:united_kingdom,
#         rebel:united_states ;
#     rebel:ethnicGroup rebel:ethnic_greek,
#         rebel:ethnic_greek_community,
#         rebel:greek,
#         rebel:greek_community,
#         rebel:people,
#         rebel:romani_people,
#         rebel:russians,
#         rebel:ukrainian,
#         rebel:ukrainian_citizens,
#         rebel:ukrainian_nationals,
#         rebel:ukrainian_people,
#         rebel:ukrainians ;
#     rebel:facetOf rebel:international_humanitarian_law ;
#     rebel:instanceOf rebel:state,
#         rebel:stateprovided,
#         rebel:stateprovided_accommodation ;
#     rebel:locatedIntheAdministrativeterritorialEntity rebel:ukraine ;
#     rebel:memberOf rebel:eu,
#         rebel:schengen,
#         rebel:un,
#         rebel:un_high_commission_for_human_rights,
#         rebel:united_nations,
#         rebel:united_nations_office_for_the_coordination_of_humanitarian_affairs ;
#     rebel:officeHeldbyHeadofGovernment rebel:president,
#         rebel:president_of_ukraine ;
#     rebel:partOf rebel:central_and_eastern_europe,
#         rebel:europe ;
#     rebel:sharesBorderwith rebel:belarus,
#         rebel:bulgaria,
#         rebel:czech_republic,
#         rebel:danish,
#         rebel:estonia,
#         rebel:eu,
#         rebel:eu_authorities,
#         rebel:german,
#         rebel:hungary,
#         rebel:iceland,
#         rebel:israel,
#         rebel:japan,
#         rebel:latvia,
#         rebel:moldova,
#         rebel:netherlands,
#         rebel:new_zealand,
#         rebel:poland,
#         rebel:polish,
#         rebel:russia,
#         rebel:russian,
#         rebel:russian_federation,
#         rebel:russians,
#         rebel:slovakia,
#         rebel:sweden,
#         rebel:switzerland,
#         rebel:turkey,
#         rebel:united_states ;
#     rebel:significantEvent rebel:ukrainian_refugees ;
#     owl:sameAs wiki:Q212 ;
#     wiki:id "Q212" .
#
# rebel:japan a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Japan" ;
#     rebel:containsAdministrativeterritorialEntity rebel:akita,
#         rebel:aomori,
#         rebel:fukuoka,
#         rebel:fukuoka_prefecture,
#         rebel:fukushima,
#         rebel:fukushima_prefecture,
#         rebel:gunma,
#         rebel:iwate,
#         rebel:kanagawa,
#         rebel:miyagi,
#         rebel:miyagi_prefecture,
#         rebel:okinawa,
#         rebel:tochigi_prefecture,
#         rebel:tokyo,
#         rebel:tōhoku,
#         rebel:tōhoku_region,
#         rebel:yamagata ;
#     rebel:diplomaticRelation rebel:abroad,
#         rebel:austria,
#         rebel:eu,
#         rebel:united_states,
#         rebel:us ;
#     rebel:highestIntheWorld rebel:highest_in_the_world ;
#     rebel:memberOf rebel:allied ;
#     rebel:ownerOf rebel:public_debt ;
#     rebel:sharesBorderwith rebel:ukraine,
#         rebel:united_states ;
#     rebel:significantEvent rebel:disaster_zone,
#         rebel:earthquake,
#         rebel:earthquake_and_tsunami,
#         rebel:kobe_earthquake,
#         rebel:tsunami,
#         rebel:world_war_ii ;
#     owl:sameAs wiki:Q17 ;
#     wiki:id "Q17" .
#
# rebel:adidas a rebel:Entity,
#         rdfs:Resource ;
#     rdfs:label "Adidas" ;
#     rebel:chairperson rebel:herbert_hainer ;
#     rebel:country rebel:australia,
#         rebel:british,
#         rebel:germany,
#         rebel:india,
#         rebel:indonesia,
#         rebel:japan,
#         rebel:new_zealand,
#         rebel:russia,
#         rebel:soviet ;
#     rebel:countryOforigin rebel:soviet ;
#     rebel:follows rebel:puma ;
#     rebel:foundedBy rebel:adi_dassler,
#         rebel:adolf_adi_dassler,
#         rebel:franz_beckenbauer,
#         rebel:tapie,
#         rebel:tapies ;
#     rebel:headquartersLocation rebel:herzogenaurach,
#         rebel:herzogenaurach_germany,
#         rebel:london ;
#     rebel:inception rebel:18_august_1949,
#         rebel:1949,
#         rebel:1967,
#         rebel:1993 ;
#     rebel:industry rebel:public_relations,
#         rebel:revenue,
#         <http://example.org/rebel/#€>,
#         <http://example.org/rebel/#€584_billion> ;
#     rebel:instanceOf rebel:holding_company,
#         rebel:trademark ;
#     rebel:locationOfformation rebel:indonesia,
#         rebel:london ;
#     rebel:namedAfter rebel:franz_beckenbauer ;
#     rebel:operatingArea rebel:asia_pacific ;
#     rebel:oppositeOf rebel:puma ;
#     rebel:ownedBy rebel:adidas,
#         rebel:crédit_lyonnais,
#         rebel:stella_mccartney,
#         rebel:tapies,
#         rebel:tapies_company ;
#     rebel:ownerOf rebel:2010_world_cup,
#         rebel:adidas_1,
#         rebel:adidas_beau_jeu,
#         rebel:adidas_in_india,
#         rebel:adidas_lacrosse,
#         rebel:adidas_predator_boot,
#         rebel:adidas_superstar,
#         rebel:adidas_trademark,
#         rebel:adidass_three_stripes,
#         rebel:all_blacks,
#         rebel:bayern_münchen,
#         rebel:energyboost,
#         rebel:fitness_world_trading,
#         rebel:futurecraft,
#         rebel:heineken_cup,
#         rebel:line_of_soviet_themed_items,
#         rebel:major_league_soccer,
#         rebel:nba,
#         rebel:new_york_yankees,
#         rebel:new_zealand_rugby_union,
#         rebel:puma,
#         rebel:puma_se,
#         rebel:pumas,
#         rebel:reebok,
#         rebel:runtastic,
#         rebel:soviet_themed_items,
#         rebel:three_stripes,
#         <http://example.org/rebel/#€584_billion> ;
#     rebel:parentOrganization rebel:adidas,
#         rebel:adidas_group,
#         rebel:crédit_lyonnais,
#         rebel:tapies ;
#     rebel:participantIn rebel:1972_summer_olympics,
#         rebel:2010_world_cup ;
#     rebel:productOrmaterialProduced rebel:aftershave,
#         rebel:asia_pacific,
#         rebel:association_football,
#         rebel:baseball_equipment,
#         rebel:basketball,
#         rebel:basketball_shoe,
#         rebel:boots,
#         rebel:clothing,
#         rebel:cricket_footwear,
#         rebel:energyboost,
#         rebel:football,
#         rebel:football_kit,
#         rebel:football_kits,
#         rebel:footwear,
#         rebel:heineken_cup,
#         rebel:leggings,
#         rebel:logo,
#         rebel:shoe,
#         rebel:shoes,
#         rebel:shorts,
#         rebel:sneakers,
#         rebel:social_media,
#         rebel:sports_bras,
#         rebel:sportswear,
#         rebel:sunglasses,
#         rebel:tracksuit,
#         rebel:trademark,
#         rebel:trainer,
#         rebel:trainers ;
#     rebel:replaces rebel:reebok ;
#     rebel:sport rebel:association_football,
#         rebel:baseball,
#         rebel:cricket,
#         rebel:football,
#         rebel:golf,
#         rebel:ice_hockey,
#         rebel:kabaddi,
#         rebel:rugby_league,
#         rebel:tennis ;
#     rebel:subsidiary rebel:adidas_in_india,
#         rebel:bayern_münchen,
#         rebel:futurecraft,
#         rebel:puma_se,
#         rebel:pumas,
#         rebel:reebok,
#         rebel:runtastic,
#         rebel:salomon_group,
#         rebel:tapies ;
#     owl:sameAs wiki:Q3895 ;
#     wiki:id "Q3895" .

# %%
# let's save the graph
g.serialize(destination="KGs/extracted_graph_for_enexa_hackathon_LLM_REBEL.ttl", format="turtle")
# Out:
# <Graph identifier=N761d051a453c467e8a917e3a8da23206 (<class 'rdflib.graph.Graph'>)>
