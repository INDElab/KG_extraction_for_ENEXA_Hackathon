# %% [markdown]
# ### 6. KG Building Notebook
#
# ##### In this notebook, we:
# 1. call the graph object.
# 2. define two namespaces and bind them to the graph:
#     * KGL = Namespace("http://example.org/ibm-KnowGL/#")
#     * WIKI = Namespace("https://www.wikidata.org/wiki/")
# 3. make entity triples and add them to the graph:
#     * (ent, RDF.type, RDFS.Resource)
#     * (ent, RDF.type, KGL.Entity)
#     * (ent, RDFS.label, Literal(key))
#     * (ent, WIKI.id, Literal(value))
#     * (ent, OWL.sameAs, wiki_ent)
# 4. make relation triples and add them to the graph:
#     * (rel, RDF.type, RDF.Property)
#     * (rel, RDF.type, KGL.Relation)
#     * (rel, WIKI.type, WIKI.Property)
#     * (rel, RDFS.label, Literal(key))
#     * (rel, WIKI.id, Literal(value))
#     * (rel, OWL.sameAs, wiki_rel)
# 5. make triples and add them to the graph:
#     * (typ, OWL.sameAs, wiki_type)
#     * (typ, RDF.type, KGL.Type)
#     * (typ, RDF.type, RDFS.Class)
#     * (typ, WIKI.id, Literal(value))
#     * (typ, RDFS.label, Literal(key))
# 6. add more semantics:
#     * (RDF.type, OWL.equivalentProperty, WIKI.P31)
#     * (RDFS.subClassOf, OWL.equivalentProperty, WIKI.P279)
#     * (RDFS.subPropertyOf, OWL.equivalentProperty, WIKI.P1647)
#     * (RDFS.member, OWL.equivalentProperty, WIKI.P361)
# 7. add the triples, both KnowGL and Wikidata, to the graph:
#     * (URIRef(KGL + subj), URIRef(KGL + pred), URIRef(KGL + obj))
#     * (URIRef(WIKI + triple[0]), URIRef(WIKI + triple[1]), URIRef(WIKI + triple[2]))
# 8. add the entity triples to the graph:
#     * (URIRef(KGL + sbj), RDF.type, URIRef(KGL + new_obj))
#     * (URIRef(KGL + sbj), RDFS.label, Literal(obj))
# 9. serialize the grap in ttl format and save it.

# %%
# we start with imports
from rdflib import Graph, URIRef, Literal, Namespace
from rdflib.namespace import RDFS, RDF, OWL, XSD
import json
import string

# %%
# Let's define some namespaces
KGL = Namespace("http://example.org/ibm-KnowGL/#")
WIKI = Namespace("https://www.wikidata.org/wiki/")

g = Graph() # create a graph object
g.bind("knowGL", KGL,  override=True) # bind the knowGL namespace to the graph
g.bind("wiki", WIKI, override=True) # bind the wiki namespace to the graph

# %%
# Let's rememeber how the library works and decide how to put into the correct format
ent = "The Beatles"
ent = ent.lower().replace(' ', '_')
ent = URIRef(KGL + ent)
print(type(ent))
print(ent)
# Out:
# <class 'rdflib.term.URIRef'>
# http://example.org/ibm-KnowGL/#the_beatles

# %%
# let's shape the relation names
rel = 'instance of'.lower().split()
if len(rel) > 1:
    words = []
    for index, word in enumerate(rel):
        if (index % 2) == 0:
            word = word.lower()   
        else:
            word = word.capitalize()
                    
        words.append(word)
    rel = ''.join(words)
rel =  URIRef(KGL + rel)
print(rel)
# Out:
# http://example.org/ibm-KnowGL/#instanceOf

# %%
#First we get the entities, relations, types and the wikidata ids from the dictionaries.
#Then we create the triples and add them to the graph.

with open('data/knowGL_wiki_entities_dict.json', 'r', encoding='utf-8') as f:
    entities = json.load(f)
print(f'Number of entities: {len(entities)}')
#print(entities)

with open('data/knowGL_wiki_relations_dict.json', 'r', encoding='utf-8') as f:
    relations = json.load(f)
print(f'Number of relations: {len(relations)}')
#print(relations)

with open('data/knowGL_wiki_types_dict.json', 'r', encoding='utf-8') as f:
    types = json.load(f)
print(f'Number of types: {len(types)}')
#print(relations)
# Out:
# Number of entities: 3109
# Number of relations: 193
# Number of types: 1092

# %%
# we create the entity triples: type: knowGL:Entity, label: entity name, id: wikidata id, sameAs: wikidata uri
for key, value in entities.items():
    if value == "no-wikiID":
        continue
    else:
        ent = key.translate(str.maketrans('', '', string.punctuation)).strip()
        ent = ent.lower().replace(' ', '_')
        ent = URIRef(KGL + ent)
        wiki_ent = URIRef(WIKI + value)
    #print(ent)
    g.add((ent, RDF.type, RDFS.Resource))
    g.add((ent, RDF.type, KGL.Entity))
    g.add((ent, RDFS.label, Literal(key)))
    g.add((ent, WIKI.id, Literal(value)))
    g.add((ent, OWL.sameAs, wiki_ent))

# %%
# we create the relation triples: knowGL:Relation, label: relation name, id: wikidata id, sameAs: wikidata uri
for key, value in relations.items():
    #print(key)
    if value == "no-wikiID":
        continue
    else:
        rel = key.translate(str.maketrans('', '', string.punctuation)).strip()
        rel = rel.lower().split()
        #print(rel)
        if len(rel) > 1:
            words = []
            for index, word in enumerate(rel):
                #print(index, word)
                if (index % 2) == 0:
                    word = word.lower()   
                elif (index % 2) == 1:
                    word = word.capitalize()         
                words.append(word)
            rel = ''.join(words)
        else:
            rel = rel[0]
        #print(rel)
        rel = URIRef(KGL + rel)
        wiki_rel = URIRef(WIKI + value)
        #print(rel)
    g.add((rel, RDF.type, RDF.Property))
    g.add((rel, RDF.type, KGL.Relation))
    g.add((rel, WIKI.type, WIKI.Property))
    g.add((rel, RDFS.label, Literal(key)))
    g.add((rel, WIKI.id, Literal(value)))
    g.add((rel, OWL.sameAs, wiki_rel))

# %%
# we create the type triples:

for key, value in types.items():
    #print(key)
    if value == "no-wikiID":
        continue
    if key == '':
        continue
    else:
        typ = key.strip().split()
    
    new_typ = []
    for x in typ:
        if x.isupper():
            x=x.upper()
        else:
            x = x.capitalize()
        new_typ.append(x)
    new_typ = ''.join(new_typ)
    #print(new_typ)
    typ = URIRef(KGL + new_typ)
    wiki_type = URIRef(WIKI + value)
    g.add((typ, OWL.sameAs, wiki_type))
    g.add((typ, RDF.type, KGL.Type))
    g.add((typ, RDF.type, RDFS.Class))
    g.add((typ, WIKI.id, Literal(value)))
    g.add((typ, RDFS.label, Literal(key)))

# %%
#Let's add more semantics for the reasoners: e.g. equivalent properties

g.add((RDF.type, OWL.equivalentProperty, WIKI.P31))
g.add((RDFS.subClassOf, OWL.equivalentProperty, WIKI.P279))
g.add((RDFS.subPropertyOf, OWL.equivalentProperty, WIKI.P1647))
g.add((RDFS.member, OWL.equivalentProperty, WIKI.P361))
# Out:
# <Graph identifier=N7f6396057093481da373edbc237d797b (<class 'rdflib.graph.Graph'>)>

# %%
# Let's add the triples to the graph
data = []
with open('data/preprocessed_data_with_KnowGL_extracted_triples_plus_wikidata.jsonl', 'r', encoding='utf-8') as f:
    for line in f:
        data.append(json.loads(line.rstrip('None\n')))
print(len(data))
# Out:
# 917

# %%
# We start with wikidata triples
for line in data:
    wiki_triples = line["Wikidata Triples"]
    for triple in wiki_triples:
        #print(triple)
        new_triples = (URIRef(WIKI + triple[0]), URIRef(WIKI + triple[1]), URIRef(WIKI + triple[2]))
        g.add(new_triples)

# %%
# Let's add the KnowGL triples

for line in data:
    knowGL_triples = line["Extracted Triples"]
    for triple in knowGL_triples:
        subj = triple[0].translate(str.maketrans('', '', string.punctuation)).strip()
        subj = subj.lower().replace(' ', '_')
        pred = triple[1].translate(str.maketrans('', '', string.punctuation)).strip().split()
        if len(pred) > 1:
            words = []
            for index, word in enumerate(pred):
                #print(index, word)
                if (index % 2) == 0:
                    word = word.lower()   
                elif (index % 2) == 1:
                    word = word.capitalize()         
                words.append(word)
            pred = ''.join(words)
        else:
            pred = pred[0]
        #print(pred)
        obj = triple[2].translate(str.maketrans('', '', string.punctuation)).strip()
        obj = obj.lower().replace(' ', '_')
        new_triples = (URIRef(KGL + subj), URIRef(KGL + pred), URIRef(KGL + obj))
        #print(new_triples)
        g.add(new_triples)

# %%
# Let's add the KnowGL type triples
for line in data:
    ent_triples = line['Entity Triples']
    for triple in ent_triples:
        sbj = triple[0].translate(str.maketrans('', '', string.punctuation)).strip()
        sbj = sbj.lower().replace(' ', '_')
        obj = triple[2].translate(str.maketrans('', '', string.punctuation)).strip()
        if triple[1] == 'type':
            obj = obj.split()
            new_obj = []
            for x in obj:
                if x.isupper():
                    x=x.upper()
                else:
                    x = x.capitalize()
                new_obj.append(x)
            new_obj = ''.join(new_obj)
            new_triple = (URIRef(KGL + sbj), RDF.type, URIRef(KGL + new_obj))
        if triple[1] == 'label':
            new_triple = (URIRef(KGL + sbj), RDFS.label, Literal(obj))
        #print(new_triple)
        g.add(new_triple)

# %% [markdown]
# Let's implant a few data type inconsitencies:

# %%
triples_with_corrupted_wikidata_ids = []

# we create the entity triples: type: knowGL:Entity, label: entity name, id: wikidata id, sameAs: wikidata uri
for key, value in entities.items():
    ent = key.translate(str.maketrans('', '', string.punctuation)).strip()
    ent = ent.lower().replace(' ', '_')
    wiki_ent = value
    if wiki_ent != "no-wikiID":
        wiki_ent = wiki_ent.strip('Q')
        #print(wiki_ent)
        corrupted_triple = (URIRef(KGL + ent), WIKI.id, Literal(wiki_ent, datatype=XSD.integer))
        #print(corrupted_triple)
        triples_with_corrupted_wikidata_ids.append(corrupted_triple)

# %%
print(len(triples_with_corrupted_wikidata_ids))

for t in triples_with_corrupted_wikidata_ids[:5]:
    print(t)
# Out:
# 2472
# (rdflib.term.URIRef('http://example.org/ibm-KnowGL/#dax'), rdflib.term.URIRef('https://www.wikidata.org/wiki/id'), rdflib.term.Literal('188878'))
# (rdflib.term.URIRef('http://example.org/ibm-KnowGL/#eu_member_state'), rdflib.term.URIRef('https://www.wikidata.org/wiki/id'), rdflib.term.Literal('44318753'))
# (rdflib.term.URIRef('http://example.org/ibm-KnowGL/#ecuador'), rdflib.term.URIRef('https://www.wikidata.org/wiki/id'), rdflib.term.Literal('736'))
# (rdflib.term.URIRef('http://example.org/ibm-KnowGL/#engelhard_corporation'), rdflib.term.URIRef('https://www.wikidata.org/wiki/id'), rdflib.term.Literal('1342078'))
# (rdflib.term.URIRef('http://example.org/ibm-KnowGL/#euro_stoxx_50'), rdflib.term.URIRef('https://www.wikidata.org/wiki/id'), rdflib.term.Literal('981010'))

# %%
### Here we add the triples with corrupted wikidata ids to the graph ###
for t in triples_with_corrupted_wikidata_ids[:100]:
    g.add(t)

# %%
# let's have a look at the graph
print(g.serialize())
# Out:
# @prefix knowGL: <http://example.org/ibm-KnowGL/#> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix wiki: <https://www.wikidata.org/wiki/> .
#
# knowGL:ATPTennisTournament a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "ATP tennis tournament" ;
#     owl:sameAs wiki:Q26863790 ;
#     wiki:id "Q26863790" .
#
# knowGL:Absorption a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "absorption" ;
#     owl:sameAs wiki:Q332828 ;
#     wiki:id "Q332828" .
#
# knowGL:AcademicConference a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "academic conference" ;
#     owl:sameAs wiki:Q2020153 ;
#     wiki:id "Q2020153" .
#
# knowGL:AcademicDepartment a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "academic department" ;
#     owl:sameAs wiki:Q2467461 ;
#     wiki:id "Q2467461" .
#
# knowGL:AcademicDiscipline a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "academic discipline" ;
#     owl:sameAs wiki:Q11862829 ;
#     wiki:id "Q11862829" .
#
# knowGL:AcademicInstitution a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "academic institution" ;
#     owl:sameAs wiki:Q4671277 ;
#     wiki:id "Q4671277" .
#
# knowGL:AcademicJournal a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "academic journal" ;
#     owl:sameAs wiki:Q737498 ;
#     wiki:id "Q737498" .
#
# knowGL:AcademicMajor a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "academic major" ;
#     owl:sameAs wiki:Q4671286 ;
#     wiki:id "Q4671286" .
#
# knowGL:Accounting a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "accounting" ;
#     owl:sameAs wiki:Q4116214 ;
#     wiki:id "Q4116214" .
#
# knowGL:Action a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "action" ;
#     owl:sameAs wiki:Q188473 ;
#     wiki:id "Q188473" .
#
# knowGL:Activity a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "activity" ;
#     owl:sameAs wiki:Q192581 ;
#     wiki:id "Q192581" .
#
# knowGL:Adhesive a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "adhesive" ;
#     owl:sameAs wiki:Q131790 ;
#     wiki:id "Q131790" .
#
# knowGL:AdministrativeRegionOfGreece a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "administrative region of Greece" ;
#     owl:sameAs wiki:Q207299 ;
#     wiki:id "Q207299" .
#
# knowGL:AdministrativeTerritorialEntity a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "administrative territorial entity" ;
#     owl:sameAs wiki:Q56061 ;
#     wiki:id "Q56061" .
#
# knowGL:AdministrativeTerritorialEntityOfCanada a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "administrative territorial entity of Canada" ;
#     owl:sameAs wiki:Q3750285 ;
#     wiki:id "Q3750285" .
#
# knowGL:Adoration a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "adoration" ;
#     owl:sameAs wiki:Q851918 ;
#     wiki:id "Q851918" .
#
# knowGL:AdvertisingAgency a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "advertising agency" ;
#     owl:sameAs wiki:Q216931 ;
#     wiki:id "Q216931" .
#
# knowGL:AdvisoryBoard a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "advisory board" ;
#     owl:sameAs wiki:Q4686866 ;
#     wiki:id "Q4686866" .
#
# knowGL:AdvocacyGroup a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "advocacy group" ;
#     owl:sameAs wiki:Q431603 ;
#     wiki:id "Q431603" .
#
# knowGL:AerialBombing a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "aerial bombing" ;
#     owl:sameAs wiki:Q111724505 ;
#     wiki:id "Q111724505" .
#
# knowGL:Agent a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "agent" ;
#     owl:sameAs wiki:Q1344174 ;
#     wiki:id "Q1344174" .
#
# knowGL:Agreement a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "agreement" ;
#     owl:sameAs wiki:Q93288 ;
#     wiki:id "Q93288" .
#
# knowGL:AirForce a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "air force" ;
#     owl:sameAs wiki:Q61883 ;
#     wiki:id "Q61883" .
#
# knowGL:AirGas a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "air gas" ;
#     owl:sameAs wiki:Q4697997 ;
#     wiki:id "Q4697997" .
#
# knowGL:AirPollutant a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "air pollutant" ;
#     owl:sameAs wiki:Q50429805 ;
#     wiki:id "Q50429805" .
#
# knowGL:AircraftComponent a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "aircraft component" ;
#     owl:sameAs wiki:Q28816538 ;
#     wiki:id "Q28816538" .
#
# knowGL:Airport a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "airport" ;
#     owl:sameAs wiki:Q1248784 ;
#     wiki:id "Q1248784" .
#
# knowGL:AirportTerminal a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "airport terminal" ;
#     owl:sameAs wiki:Q849706 ;
#     wiki:id "Q849706" .
#
# knowGL:Allotrope a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "allotrope" ;
#     owl:sameAs wiki:Q21198401 ;
#     wiki:id "Q21198401" .
#
# knowGL:AllotropeOfOxygen a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "allotrope of oxygen" ;
#     owl:sameAs wiki:Q428653 ;
#     wiki:id "Q428653" .
#
# knowGL:Alloy a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "alloy" ;
#     owl:sameAs wiki:Q37756 ;
#     wiki:id "Q37756" .
#
# knowGL:Ambassador a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "ambassador" ;
#     owl:sameAs wiki:Q121998 ;
#     wiki:id "Q121998" .
#
# knowGL:AnatomicalStructure a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "anatomical structure" ;
#     owl:sameAs wiki:Q112826905 ;
#     wiki:id "Q112826905" .
#
# knowGL:AnimalProduct a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "animal product" ;
#     owl:sameAs wiki:Q629103 ;
#     wiki:id "Q629103" .
#
# knowGL:Annexation a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "annexation" ;
#     owl:sameAs wiki:Q194465 ;
#     wiki:id "Q194465" .
#
# knowGL:Apartment a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "apartment" ;
#     owl:sameAs wiki:Q188507 ;
#     wiki:id "Q188507" .
#
# knowGL:ApartmentBuilding a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "apartment building" ;
#     owl:sameAs wiki:Q13402009 ;
#     wiki:id "Q13402009" .
#
# knowGL:App a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "app" ;
#     owl:sameAs wiki:Q620615 ;
#     wiki:id "Q620615" .
#
# knowGL:Application a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "application" ;
#     owl:sameAs wiki:Q166142 ;
#     wiki:id "Q166142" .
#
# knowGL:Archipelago a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "archipelago" ;
#     owl:sameAs wiki:Q33837 ;
#     wiki:id "Q33837" .
#
# knowGL:ArchitecturalElement a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "architectural element" ;
#     owl:sameAs wiki:Q391414 ;
#     wiki:id "Q391414" .
#
# knowGL:ArchitecturalFirm a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "architectural firm" ;
#     owl:sameAs wiki:Q4387609 ;
#     wiki:id "Q4387609" .
#
# knowGL:ArchitecturalStructure a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "architectural structure" ;
#     owl:sameAs wiki:Q811979 ;
#     wiki:id "Q811979" .
#
# knowGL:Archives a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "archives" ;
#     owl:sameAs wiki:Q166118 ;
#     wiki:id "Q166118" .
#
# knowGL:Arena a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "arena" ;
#     owl:sameAs wiki:Q641226 ;
#     wiki:id "Q641226" .
#
# knowGL:ArmedForces a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "armed forces" ;
#     owl:sameAs wiki:Q8473 ;
#     wiki:id "Q8473" .
#
# knowGL:ArmedOrganization a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "armed organization" ;
#     owl:sameAs wiki:Q17149090 ;
#     wiki:id "Q17149090" .
#
# knowGL:Army a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "army" ;
#     owl:sameAs wiki:Q8473 ;
#     wiki:id "Q8473" .
#
# knowGL:ArtGenre a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "art genre" ;
#     owl:sameAs wiki:Q1792379 ;
#     wiki:id "Q1792379" .
#
# knowGL:ArtificialPhysicalObject a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "artificial physical object" ;
#     owl:sameAs wiki:Q8205328 ;
#     wiki:id "Q8205328" .
#
# knowGL:ArtificialSatellite a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "artificial satellite" ;
#     owl:sameAs wiki:Q26540 ;
#     wiki:id "Q26540" .
#
# knowGL:AspectOfHistory a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "aspect of history" ;
#     owl:sameAs wiki:Q17524420 ;
#     wiki:id "Q17524420" .
#
# knowGL:Assault a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "assault" ;
#     owl:sameAs wiki:Q365680 ;
#     wiki:id "Q365680" .
#
# knowGL:AssociationFootballClub a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "association football club" ;
#     owl:sameAs wiki:Q476028 ;
#     wiki:id "Q476028" .
#
# knowGL:AssociationFootballCompetition a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "association football competition" ;
#     owl:sameAs wiki:Q1478437 ;
#     wiki:id "Q1478437" .
#
# knowGL:AssociationFootballFederation a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "association football federation" ;
#     owl:sameAs wiki:Q1478443 ;
#     wiki:id "Q1478443" .
#
# knowGL:AssociationFootballFinal a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "association football final" ;
#     owl:sameAs wiki:Q65770283 ;
#     wiki:id "Q65770283" .
#
# knowGL:AssociationFootballLeague a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "association football league" ;
#     owl:sameAs wiki:Q15991303 ;
#     wiki:id "Q15991303" .
#
# knowGL:AssociationFootballMatch a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "association football match" ;
#     owl:sameAs wiki:Q12166442 ;
#     wiki:id "Q12166442" .
#
# knowGL:AssociationFootballPosition a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "association football position" ;
#     owl:sameAs wiki:Q4611891 ;
#     wiki:id "Q4611891" .
#
# knowGL:AssociationFootballStadium a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "association football stadium" ;
#     owl:sameAs wiki:Q1154710 ;
#     wiki:id "Q1154710" .
#
# knowGL:Asteroid a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "asteroid" ;
#     owl:sameAs wiki:Q3863 ;
#     wiki:id "Q3863" .
#
# knowGL:AstronomicalObservatory a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "astronomical observatory" ;
#     owl:sameAs wiki:Q1254933 ;
#     wiki:id "Q1254933" .
#
# knowGL:AstronomicalSurvey a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "astronomical survey" ;
#     owl:sameAs wiki:Q550089 ;
#     wiki:id "Q550089" .
#
# knowGL:Atmosphere a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "atmosphere" ;
#     owl:sameAs wiki:Q8104 ;
#     wiki:id "Q8104" .
#
# knowGL:AtmosphericCirculation a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "atmospheric circulation" ;
#     owl:sameAs wiki:Q2615451 ;
#     wiki:id "Q2615451" .
#
# knowGL:AtmosphericCloud a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "atmospheric cloud" ;
#     owl:sameAs wiki:Q90023606 ;
#     wiki:id "Q90023606" .
#
# knowGL:AtmosphericHole a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "atmospheric hole" ;
#     owl:sameAs wiki:Q107817304 ;
#     wiki:id "Q107817304" .
#
# knowGL:AtmosphericLayer a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "atmospheric layer" ;
#     owl:sameAs wiki:Q29653271 ;
#     wiki:id "Q29653271" .
#
# knowGL:AtmosphericOrInterstellarBoundary a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "atmospheric or interstellar boundary" ;
#     owl:sameAs wiki:Q26509571 ;
#     wiki:id "Q26509571" .
#
# knowGL:AtmosphericOzoneLayer a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "atmospheric ozone layer" ;
#     owl:sameAs wiki:Q79995 ;
#     wiki:id "Q79995" .
#
# knowGL:AtmosphericPhenomenon a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "atmospheric phenomenon" ;
#     owl:sameAs wiki:Q4072190 ;
#     wiki:id "Q4072190" .
#
# knowGL:Atom a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "atom" ;
#     owl:sameAs wiki:Q9121 ;
#     wiki:id "Q9121" .
#
# knowGL:AtrocityCrime a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "atrocity crime" ;
#     owl:sameAs wiki:Q113549029 ;
#     wiki:id "Q113549029" .
#
# knowGL:AudiovisualWork a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "audiovisual work" ;
#     owl:sameAs wiki:Q2431196 ;
#     wiki:id "Q2431196" .
#
# knowGL:AutoRacingTrack a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "auto racing track" ;
#     owl:sameAs wiki:Q2338524 ;
#     wiki:id "Q2338524" .
#
# knowGL:AutomobileManufacturer a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "automobile manufacturer" ;
#     owl:sameAs wiki:Q786820 ;
#     wiki:id "Q786820" .
#
# knowGL:AutomobileModel a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "automobile model" ;
#     owl:sameAs wiki:Q3231690 ;
#     wiki:id "Q3231690" .
#
# knowGL:AutomobileModelSeries a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "automobile model series" ;
#     owl:sameAs wiki:Q59773381 ;
#     wiki:id "Q59773381" .
#
# knowGL:AutonomousCommunityOfSpain a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "autonomous community of Spain" ;
#     owl:sameAs wiki:Q10742 ;
#     wiki:id "Q10742" .
#
# <http://example.org/ibm-KnowGL/#AutonomousRegionOfThePeople'sRepublicOfChina> a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "autonomous region of the People's Republic of China" ;
#     owl:sameAs wiki:Q57362 ;
#     wiki:id "Q57362" .
#
# knowGL:AutonomousTerritorialUnitOfMoldova a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "Autonomous territorial unit of Moldova" ;
#     owl:sameAs wiki:Q4826865 ;
#     wiki:id "Q4826865" .
#
# knowGL:Award a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "award" ;
#     owl:sameAs wiki:Q618779 ;
#     wiki:id "Q618779" .
#
# knowGL:Ball a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "ball" ;
#     owl:sameAs wiki:Q9384 ;
#     wiki:id "Q9384" .
#
# knowGL:Bank a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "bank" ;
#     owl:sameAs wiki:Q22687 ;
#     wiki:id "Q22687" .
#
# knowGL:BaseballLeague a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "baseball league" ;
#     owl:sameAs wiki:Q6631808 ;
#     wiki:id "Q6631808" .
#
# knowGL:BaseballPark a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "baseball park" ;
#     owl:sameAs wiki:Q595452 ;
#     wiki:id "Q595452" .
#
# knowGL:BaseballTeam a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "baseball team" ;
#     owl:sameAs wiki:Q13027888 ;
#     wiki:id "Q13027888" .
#
# knowGL:BasketballLeague a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "basketball league" ;
#     owl:sameAs wiki:Q18536323 ;
#     wiki:id "Q18536323" .
#
# knowGL:BasketballPosition a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "basketball position" ;
#     owl:sameAs wiki:Q1148974 ;
#     wiki:id "Q1148974" .
#
# knowGL:BasketballShoe a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "basketball shoe" ;
#     owl:sameAs wiki:Q14552454 ;
#     wiki:id "Q14552454" .
#
# knowGL:BasketballTeam a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "basketball team" ;
#     owl:sameAs wiki:Q13393265 ;
#     wiki:id "Q13393265" .
#
# knowGL:Battle a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "battle" ;
#     owl:sameAs wiki:Q178561 ;
#     wiki:id "Q178561" .
#
# knowGL:Bay a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "bay" ;
#     owl:sameAs wiki:Q39594 ;
#     wiki:id "Q39594" .
#
# knowGL:Bedding a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "bedding" ;
#     owl:sameAs wiki:Q1762457 ;
#     wiki:id "Q1762457" .
#
# knowGL:Behavior a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "behavior" ;
#     owl:sameAs wiki:Q9332 ;
#     wiki:id "Q9332" .
#
# knowGL:BicameralLegislature a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "bicameral legislature" ;
#     owl:sameAs wiki:Q189445 ;
#     wiki:id "Q189445" .
#
# knowGL:BigCity a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "big city" ;
#     owl:sameAs wiki:Q1549591 ;
#     wiki:id "Q1549591" .
#
# knowGL:BilateralRelation a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "bilateral relation" ;
#     owl:sameAs wiki:Q15221623 ;
#     wiki:id "Q15221623" .
#
# knowGL:Biochemistry a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "biochemistry" ;
#     owl:sameAs wiki:Q7094 ;
#     wiki:id "Q7094" .
#
# knowGL:BiochemistryMethod a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "biochemistry method" ;
#     owl:sameAs wiki:Q26879200 ;
#     wiki:id "Q26879200" .
#
# knowGL:BiochemistryTechnique a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "biochemistry technique" ;
#     owl:sameAs wiki:Q26879200 ;
#     wiki:id "Q26879200" .
#
# knowGL:Biofabric a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "biofabric" ;
#     owl:sameAs wiki:Q19867172 ;
#     wiki:id "Q19867172" .
#
# knowGL:BiogeochemicalCycle a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "biogeochemical cycle" ;
#     owl:sameAs wiki:Q846303 ;
#     wiki:id "Q846303" .
#
# knowGL:BiogeographicRealm a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "biogeographic realm" ;
#     owl:sameAs wiki:Q944816 ;
#     wiki:id "Q944816" .
#
# knowGL:BiologicalDatabase a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "biological database" ;
#     owl:sameAs wiki:Q4117139 ;
#     wiki:id "Q4117139" .
#
# knowGL:BiologicalProcess a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "biological process" ;
#     owl:sameAs wiki:Q2996394 ;
#     wiki:id "Q2996394" .
#
# knowGL:Biome a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "biome" ;
#     owl:sameAs wiki:Q101998 ;
#     wiki:id "Q101998" .
#
# knowGL:Biozone a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "biozone" ;
#     owl:sameAs wiki:Q2110260 ;
#     wiki:id "Q2110260" .
#
# knowGL:BodyOfWater a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "body of water" ;
#     owl:sameAs wiki:Q15324 ;
#     wiki:id "Q15324" .
#
# knowGL:Bog a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "bog" ;
#     owl:sameAs wiki:Q1681353 ;
#     wiki:id "Q1681353" .
#
# knowGL:BombAttack a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "bomb attack" ;
#     owl:sameAs wiki:Q891854 ;
#     wiki:id "Q891854" .
#
# knowGL:Bond a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "bond" ;
#     owl:sameAs wiki:Q11693 ;
#     wiki:id "Q11693" .
#
# knowGL:Boot a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "boot" ;
#     owl:sameAs wiki:Q190868 ;
#     wiki:id "Q190868" .
#
# knowGL:BoroughInTheUnitedKingdom a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "borough in the United Kingdom" ;
#     owl:sameAs wiki:Q1006876 ;
#     wiki:id "Q1006876" .
#
# knowGL:BoroughOfNewYorkCity a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "borough of New York City" ;
#     owl:sameAs wiki:Q408804 ;
#     wiki:id "Q408804" .
#
# knowGL:BranchOfPhysics a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "branch of physics" ;
#     owl:sameAs wiki:Q4162444 ;
#     wiki:id "Q4162444" .
#
# knowGL:BranchOfScience a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "branch of science" ;
#     owl:sameAs wiki:Q2465832 ;
#     wiki:id "Q2465832" .
#
# knowGL:Brand a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "brand" ;
#     owl:sameAs wiki:Q431289 ;
#     wiki:id "Q431289" .
#
# knowGL:BrickAndMortar a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "brick and mortar" ;
#     owl:sameAs wiki:Q726870 ;
#     wiki:id "Q726870" .
#
# knowGL:Broadcaster a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "broadcaster" ;
#     owl:sameAs wiki:Q15265344 ;
#     wiki:id "Q15265344" .
#
# knowGL:Bronchospasm a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "bronchospasm" ;
#     owl:sameAs wiki:Q279330 ;
#     wiki:id "Q279330" .
#
# knowGL:Building a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "building" ;
#     owl:sameAs wiki:Q41176 ;
#     wiki:id "Q41176" .
#
# knowGL:BuildingComplex a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "building complex" ;
#     owl:sameAs wiki:Q1497364 ;
#     wiki:id "Q1497364" .
#
# knowGL:BuildingMaterial a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "building material" ;
#     owl:sameAs wiki:Q206615 ;
#     wiki:id "Q206615" .
#
# knowGL:Burn a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "burn" ;
#     owl:sameAs wiki:Q63565252 ;
#     wiki:id "Q63565252" .
#
# knowGL:Business a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "business" ;
#     owl:sameAs wiki:Q4830453 ;
#     wiki:id "Q4830453" .
#
# knowGL:BusinessSchool a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "business school" ;
#     owl:sameAs wiki:Q1143635 ;
#     wiki:id "Q1143635" .
#
# knowGL:BusinessUnit a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "business unit" ;
#     owl:sameAs wiki:Q261232 ;
#     wiki:id "Q261232" .
#
# knowGL:Cabinet a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "cabinet" ;
#     owl:sameAs wiki:Q640506 ;
#     wiki:id "Q640506" .
#
# knowGL:CalendarMonth a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "calendar month" ;
#     owl:sameAs wiki:Q47018478 ;
#     wiki:id "Q47018478" .
#
# knowGL:Camp a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "camp" ;
#     owl:sameAs wiki:Q876852 ;
#     wiki:id "Q876852" .
#
# knowGL:CampaignGroup a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "campaign group" ;
#     owl:sameAs wiki:Q45215078 ;
#     wiki:id "Q45215078" .
#
# knowGL:CanadianFederalGeneralElection a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "Canadian federal general election" ;
#     owl:sameAs wiki:Q849095 ;
#     wiki:id "Q849095" .
#
# knowGL:Capital a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "capital" ;
#     owl:sameAs wiki:Q193893 ;
#     wiki:id "Q193893" .
#
# knowGL:Capitalization a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "capitalization" ;
#     owl:sameAs wiki:Q425951 ;
#     wiki:id "Q425951" .
#
# knowGL:Carcinoma a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "carcinoma" ;
#     owl:sameAs wiki:Q33525 ;
#     wiki:id "Q33525" .
#
# knowGL:CardinalBodyPart a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "cardinal body part" ;
#     owl:sameAs wiki:Q17781690 ;
#     wiki:id "Q17781690" .
#
# knowGL:CauseOfDeath a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "cause of death" ;
#     owl:sameAs wiki:Q1931388 ;
#     wiki:id "Q1931388" .
#
# knowGL:CellType a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "cell type" ;
#     owl:sameAs wiki:Q189118 ;
#     wiki:id "Q189118" .
#
# knowGL:CellTypeBenignNeoplasm a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "cell type benign neoplasm" ;
#     owl:sameAs wiki:Q18553645 ;
#     wiki:id "Q18553645" .
#
# knowGL:CellularComponent a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "cellular component" ;
#     owl:sameAs wiki:Q5058355 ;
#     wiki:id "Q5058355" .
#
# knowGL:CentralBank a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "central bank" ;
#     owl:sameAs wiki:Q66344 ;
#     wiki:id "Q66344" .
#
# knowGL:CentralGovernment a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "central government" ;
#     owl:sameAs wiki:Q2767140 ;
#     wiki:id "Q2767140" .
#
# knowGL:CentralRepresentation a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "Central Representation" ;
#     owl:sameAs wiki:Q60683361 ;
#     wiki:id "Q60683361" .
#
# knowGL:CeremonialCountyOfEngland a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "ceremonial county of England" ;
#     owl:sameAs wiki:Q180673 ;
#     wiki:id "Q180673" .
#
# knowGL:Championship a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "championship" ;
#     owl:sameAs wiki:Q1079023 ;
#     wiki:id "Q1079023" .
#
# knowGL:Change a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "change" ;
#     owl:sameAs wiki:Q1150070 ;
#     wiki:id "Q1150070" .
#
# knowGL:CharitableOrganization a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "charitable organization" ;
#     owl:sameAs wiki:Q708676 ;
#     wiki:id "Q708676" .
#
# knowGL:Cheating a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "cheating" ;
#     owl:sameAs wiki:Q2914621 ;
#     wiki:id "Q2914621" .
#
# knowGL:ChemicalAccident a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "chemical accident" ;
#     owl:sameAs wiki:Q977367 ;
#     wiki:id "Q977367" .
#
# knowGL:ChemicalCompany a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "chemical company" ;
#     owl:sameAs wiki:Q90285334 ;
#     wiki:id "Q90285334" .
#
# knowGL:ChemicalElement a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "chemical element" ;
#     owl:sameAs wiki:Q11344 ;
#     wiki:id "Q11344" .
#
# knowGL:ChemicalEquation a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "chemical equation" ;
#     owl:sameAs wiki:Q182527 ;
#     wiki:id "Q182527" .
#
# knowGL:ChemicalIndustry a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "Chemical industry" ;
#     owl:sameAs wiki:Q207652 ;
#     wiki:id "Q207652" .
#
# knowGL:ChemicalIndustryGroup a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "Chemical Industry Group",
#         "Chemical industry group" ;
#     owl:sameAs wiki:Q84297541 ;
#     wiki:id "Q84297541" .
#
# knowGL:ChemicalProcess a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "chemical process" ;
#     owl:sameAs wiki:Q2281940 ;
#     wiki:id "Q2281940" .
#
# knowGL:ChemicalQuantity a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "chemical quantity" ;
#     owl:sameAs wiki:Q71550700 ;
#     wiki:id "Q71550700" .
#
# knowGL:ChemicalReaction a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "chemical reaction" ;
#     owl:sameAs wiki:Q36534 ;
#     wiki:id "Q36534" .
#
# knowGL:ChemicalSubstance a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "chemical substance" ;
#     owl:sameAs wiki:Q79529 ;
#     wiki:id "Q79529" .
#
# knowGL:ChemicalSubstanceAbuse a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "chemical substance abuse" ;
#     owl:sameAs wiki:Q3184856 ;
#     wiki:id "Q3184856" .
#
# knowGL:Child a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "child" ;
#     owl:sameAs wiki:Q7569 ;
#     wiki:id "Q7569" .
#
# knowGL:Chlorine a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "chlorine" ;
#     owl:sameAs wiki:Q688 ;
#     wiki:id "Q688" .
#
# knowGL:ChurchBuilding a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "church building" ;
#     owl:sameAs wiki:Q16970 ;
#     wiki:id "Q16970" .
#
# knowGL:CircleOfLatitude a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "circle of latitude" ;
#     owl:sameAs wiki:Q146591 ;
#     wiki:id "Q146591" .
#
# knowGL:Circulation a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "circulation" ;
#     owl:sameAs wiki:Q578091 ;
#     wiki:id "Q578091" .
#
# knowGL:City a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "city" ;
#     owl:sameAs wiki:Q515 ;
#     wiki:id "Q515" .
#
# <http://example.org/ibm-KnowGL/#City/town> a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "city/town" ;
#     owl:sameAs wiki:Q106389302 ;
#     wiki:id "Q106389302" .
#
# knowGL:CityOfJapan a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "city of Japan" ;
#     owl:sameAs wiki:Q494721 ;
#     wiki:id "Q494721" .
#
# knowGL:CityOfRegionalSignificanceOfUkraine a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "city of regional significance of Ukraine" ;
#     owl:sameAs wiki:Q5123999 ;
#     wiki:id "Q5123999" .
#
# knowGL:CityOfTheUnitedStates a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "city of the United States" ;
#     owl:sameAs wiki:Q1093829 ;
#     wiki:id "Q1093829" .
#
# knowGL:CityWithMillionsOfInhabitants a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "city with millions of inhabitants" ;
#     owl:sameAs wiki:Q1637706 ;
#     wiki:id "Q1637706" .
#
# knowGL:CityWithPowiatRights a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "city with powiat rights" ;
#     owl:sameAs wiki:Q925381 ;
#     wiki:id "Q925381" .
#
# knowGL:CivilWar a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "civil war" ;
#     owl:sameAs wiki:Q8676 ;
#     wiki:id "Q8676" .
#
# knowGL:ClassOfAward a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "class of award" ;
#     owl:sameAs wiki:Q38033430 ;
#     wiki:id "Q38033430" .
#
# knowGL:ClassOfChemicalCompoundsWithSimilarApplicationsOrFunctions a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "class of chemical compounds with similar applications or functions" ;
#     owl:sameAs wiki:Q56256173 ;
#     wiki:id "Q56256173" .
#
# knowGL:ClassOfChemicalSubstancesByUse a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "class of chemical substances by use" ;
#     owl:sameAs wiki:Q100434640 ;
#     wiki:id "Q100434640" .
#
# knowGL:CleaningProduct a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "cleaning product" ;
#     owl:sameAs wiki:Q1974312 ;
#     wiki:id "Q1974312" .
#
# knowGL:ClimateChange a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "climate change" ;
#     owl:sameAs wiki:Q125928 ;
#     wiki:id "Q125928" .
#
# knowGL:ClimateChangeMitigation a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "climate change mitigation" ;
#     owl:sameAs wiki:Q898653 ;
#     wiki:id "Q898653" .
#
# knowGL:ClinicalSign a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "clinical sign" ;
#     owl:sameAs wiki:Q1441305 ;
#     wiki:id "Q1441305" .
#
# knowGL:Clothing a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "clothing" ;
#     owl:sameAs wiki:Q11460 ;
#     wiki:id "Q11460" .
#
# knowGL:ClothingStore a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "clothing store" ;
#     owl:sameAs wiki:Q2090555 ;
#     wiki:id "Q2090555" .
#
# knowGL:Cloud a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "cloud" ;
#     owl:sameAs wiki:Q8074 ;
#     wiki:id "Q8074" .
#
# knowGL:CloudGenera a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "cloud genera" ;
#     owl:sameAs wiki:Q1840368 ;
#     wiki:id "Q1840368" .
#
# knowGL:Coal a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "coal" ;
#     owl:sameAs wiki:Q24489 ;
#     wiki:id "Q24489" .
#
# knowGL:CoalTar a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "coal tar" ;
#     owl:sameAs wiki:Q948232 ;
#     wiki:id "Q948232" .
#
# knowGL:CodeOfLaw a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "code of law" ;
#     owl:sameAs wiki:Q922203 ;
#     wiki:id "Q922203" .
#
# knowGL:CollectiveHeadOfState a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "collective head of state" ;
#     owl:sameAs wiki:Q22950320 ;
#     wiki:id "Q22950320" .
#
# knowGL:Color a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "color" ;
#     owl:sameAs wiki:Q1075 ;
#     wiki:id "Q1075" .
#
# knowGL:Colourant a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "colourant" ;
#     owl:sameAs wiki:Q911922 ;
#     wiki:id "Q911922" .
#
# knowGL:CommercialCompany a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "commercial company" ;
#     owl:sameAs wiki:Q567521 ;
#     wiki:id "Q567521" .
#
# knowGL:CommercialTrafficAerodrome a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "commercial traffic aerodrome" ;
#     owl:sameAs wiki:Q94993988 ;
#     wiki:id "Q94993988" .
#
# knowGL:Committee a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "committee" ;
#     owl:sameAs wiki:Q865588 ;
#     wiki:id "Q865588" .
#
# knowGL:CommuneOfFrance a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "commune of France" ;
#     owl:sameAs wiki:Q484170 ;
#     wiki:id "Q484170" .
#
# knowGL:CommunitySchool a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "community school" ;
#     owl:sameAs wiki:Q5155053 ;
#     wiki:id "Q5155053" .
#
# knowGL:Company a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "company" ;
#     owl:sameAs wiki:Q783794 ;
#     wiki:id "Q783794" .
#
# knowGL:Competition a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "competition" ;
#     owl:sameAs wiki:Q476300 ;
#     wiki:id "Q476300" .
#
# knowGL:CompetitionAndMarketsAuthority a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "Competition and Markets Authority" ;
#     owl:sameAs wiki:Q18363996 ;
#     wiki:id "Q18363996" .
#
# knowGL:CompetitionClass a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "competition class" ;
#     owl:sameAs wiki:Q22936940 ;
#     wiki:id "Q22936940" .
#
# knowGL:CompetitionCommission a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "Competition Commission" ;
#     owl:sameAs wiki:Q2565834 ;
#     wiki:id "Q2565834" .
#
# knowGL:CompositeMaterial a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "composite material" ;
#     owl:sameAs wiki:Q181790 ;
#     wiki:id "Q181790" .
#
# knowGL:CompositeParticle a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "composite particle" ;
#     owl:sameAs wiki:Q3366856 ;
#     wiki:id "Q3366856" .
#
# knowGL:ComputerHardware a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "computer hardware" ;
#     owl:sameAs wiki:Q3966 ;
#     wiki:id "Q3966" .
#
# knowGL:ComputerModel a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "computer model" ;
#     owl:sameAs wiki:Q29876482 ;
#     wiki:id "Q29876482" .
#
# knowGL:ComputerNetworkProtocol a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "computer network protocol" ;
#     owl:sameAs wiki:Q15836568 ;
#     wiki:id "Q15836568" .
#
# knowGL:ComputerVulnerability a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "computer vulnerability" ;
#     owl:sameAs wiki:Q114262284 ;
#     wiki:id "Q114262284" .
#
# knowGL:ComuneOfItaly a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "comune of Italy" ;
#     owl:sameAs wiki:Q747074 ;
#     wiki:id "Q747074" .
#
# knowGL:ConcentrationCamp a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "concentration camp" ;
#     owl:sameAs wiki:Q152081 ;
#     wiki:id "Q152081" .
#
# knowGL:Concept a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "concept" ;
#     owl:sameAs wiki:Q151885 ;
#     wiki:id "Q151885" .
#
# <http://example.org/ibm-KnowGL/#ConceyuD'asturies> a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "Conceyu d'Asturies" ;
#     owl:sameAs wiki:Q5055981 ;
#     wiki:id "Q5055981" .
#
# knowGL:Condition a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "condition" ;
#     owl:sameAs wiki:Q12136 ;
#     wiki:id "Q12136" .
#
# knowGL:Conflict a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "conflict" ;
#     owl:sameAs wiki:Q198 ;
#     wiki:id "Q198" .
#
# knowGL:Conglomerate a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "conglomerate" ;
#     owl:sameAs wiki:Q778575 ;
#     wiki:id "Q778575" .
#
# knowGL:Constitution a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "constitution" ;
#     owl:sameAs wiki:Q7755 ;
#     wiki:id "Q7755" .
#
# knowGL:ConsumerAffairsAgency a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "consumer affairs agency" ;
#     owl:sameAs wiki:Q5164637 ;
#     wiki:id "Q5164637" .
#
# knowGL:Container a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "container" ;
#     owl:sameAs wiki:Q987767 ;
#     wiki:id "Q987767" .
#
# knowGL:Continent a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "continent" ;
#     owl:sameAs wiki:Q5107 ;
#     wiki:id "Q5107" .
#
# knowGL:Convention a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "convention" ;
#     owl:sameAs wiki:Q131569 ;
#     wiki:id "Q131569" .
#
# knowGL:Cooperative a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "cooperative" ;
#     owl:sameAs wiki:Q4539 ;
#     wiki:id "Q4539" .
#
# knowGL:CooperativeSociety a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "cooperative society" ;
#     owl:sameAs wiki:Q4539 ;
#     wiki:id "Q4539" .
#
# knowGL:Copolymer a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "copolymer" ;
#     owl:sameAs wiki:Q421281 ;
#     wiki:id "Q421281" .
#
# knowGL:CorporateFinance a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "corporate finance" ;
#     owl:sameAs wiki:Q1134763 ;
#     wiki:id "Q1134763" .
#
# knowGL:CorporateTitle a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "corporate title" ;
#     owl:sameAs wiki:Q11488158 ;
#     wiki:id "Q11488158" .
#
# knowGL:Corps a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "corps" ;
#     owl:sameAs wiki:Q188497 ;
#     wiki:id "Q188497" .
#
# knowGL:Corruption a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "corruption" ;
#     owl:sameAs wiki:Q366 ;
#     wiki:id "Q366" .
#
# knowGL:Cosmetics a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "cosmetics" ;
#     owl:sameAs wiki:Q131207 ;
#     wiki:id "Q131207" .
#
# knowGL:CostEffectiveness a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "cost effectiveness" ;
#     owl:sameAs wiki:Q104952813 ;
#     wiki:id "Q104952813" .
#
# knowGL:CostumeAccessory a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "costume accessory" ;
#     owl:sameAs wiki:Q1065579 ;
#     wiki:id "Q1065579" .
#
# knowGL:Council a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "council" ;
#     owl:sameAs wiki:Q4358176 ;
#     wiki:id "Q4358176" .
#
# knowGL:Country a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "country" ;
#     owl:sameAs wiki:Q6256 ;
#     wiki:id "Q6256" .
#
# knowGL:CountyOfCalifornia a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "county of California" ;
#     owl:sameAs wiki:Q13212489 ;
#     wiki:id "Q13212489" .
#
# knowGL:CountyOfMissouri a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "county of Missouri" ;
#     owl:sameAs wiki:Q13410520 ;
#     wiki:id "Q13410520" .
#
# knowGL:CountyOfNorway a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "county of Norway" ;
#     owl:sameAs wiki:Q192299 ;
#     wiki:id "Q192299" .
#
# knowGL:CreativeWork a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "creative work" ;
#     owl:sameAs wiki:Q386724 ;
#     wiki:id "Q386724" .
#
# knowGL:CreditInstitution a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "credit institution" ;
#     owl:sameAs wiki:Q730038 ;
#     wiki:id "Q730038" .
#
# knowGL:CreditRatingAgency a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "credit rating agency" ;
#     owl:sameAs wiki:Q765517 ;
#     wiki:id "Q765517" .
#
# knowGL:CricketBat a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "cricket bat" ;
#     owl:sameAs wiki:Q577263 ;
#     wiki:id "Q577263" .
#
# knowGL:CricketTeam a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "cricket team" ;
#     owl:sameAs wiki:Q17376093 ;
#     wiki:id "Q17376093" .
#
# knowGL:Crime a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "crime" ;
#     owl:sameAs wiki:Q83267 ;
#     wiki:id "Q83267" .
#
# knowGL:CriminalOrganization a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "criminal organization" ;
#     owl:sameAs wiki:Q1788992 ;
#     wiki:id "Q1788992" .
#
# knowGL:Crisis a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "crisis" ;
#     owl:sameAs wiki:Q381072 ;
#     wiki:id "Q381072" .
#
# knowGL:Crop a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "crop" ;
#     owl:sameAs wiki:Q235352 ;
#     wiki:id "Q235352" .
#
# knowGL:CrudePetroleum a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "crude petroleum" ;
#     owl:sameAs wiki:Q3412078 ;
#     wiki:id "Q3412078" .
#
# knowGL:Cultivar a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "cultivar" ;
#     owl:sameAs wiki:Q4886 ;
#     wiki:id "Q4886" .
#
# knowGL:CulturalHeritage a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "cultural heritage" ;
#     owl:sameAs wiki:Q210272 ;
#     wiki:id "Q210272" .
#
# knowGL:CulturalRegion a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "cultural region" ;
#     owl:sameAs wiki:Q3502482 ;
#     wiki:id "Q3502482" .
#
# knowGL:Culture a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "culture" ;
#     owl:sameAs wiki:Q11042 ;
#     wiki:id "Q11042" .
#
# knowGL:CultureOfAnArea a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "culture of an area" ;
#     owl:sameAs wiki:Q19958368 ;
#     wiki:id "Q19958368" .
#
# knowGL:Currency a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "currency" ;
#     owl:sameAs wiki:Q8142 ;
#     wiki:id "Q8142" .
#
# knowGL:Cyclone a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "cyclone" ;
#     owl:sameAs wiki:Q79602 ;
#     wiki:id "Q79602" .
#
# knowGL:DNASequence a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "DNA sequence" ;
#     owl:sameAs wiki:Q23933850 ;
#     wiki:id "Q23933850" .
#
# knowGL:DailyNewspaper a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "daily newspaper" ;
#     owl:sameAs wiki:Q1110794 ;
#     wiki:id "Q1110794" .
#
# knowGL:DataCenter a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "data center" ;
#     owl:sameAs wiki:Q671224 ;
#     wiki:id "Q671224" .
#
# knowGL:DataHarmonization a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "data harmonization" ;
#     owl:sameAs wiki:Q30698143 ;
#     wiki:id "Q30698143" .
#
# knowGL:DataSet a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "data set" ;
#     owl:sameAs wiki:Q1172284 ;
#     wiki:id "Q1172284" .
#
# knowGL:Database a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "database" ;
#     owl:sameAs wiki:Q8513 ;
#     wiki:id "Q8513" .
#
# knowGL:DeFactoEmbassy a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "de facto embassy" ;
#     owl:sameAs wiki:Q5244910 ;
#     wiki:id "Q5244910" .
#
# knowGL:DebtRatio a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "debt ratio" ;
#     owl:sameAs wiki:Q2234049 ;
#     wiki:id "Q2234049" .
#
# knowGL:Decay a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "decay" ;
#     owl:sameAs wiki:Q3332922 ;
#     wiki:id "Q3332922" .
#
# knowGL:Defence a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "defence" ;
#     owl:sameAs wiki:Q1985622 ;
#     wiki:id "Q1985622" .
#
# knowGL:DefenseMinistry a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "defense ministry" ;
#     owl:sameAs wiki:Q1862884 ;
#     wiki:id "Q1862884" .
#
# knowGL:Definition a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "definition" ;
#     owl:sameAs wiki:Q101072 ;
#     wiki:id "Q101072" .
#
# knowGL:Delict a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "delict" ;
#     owl:sameAs wiki:Q1456832 ;
#     wiki:id "Q1456832" .
#
# knowGL:DemographicsOfCountryOrRegion a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "demographics of country or region" ;
#     owl:sameAs wiki:Q23983664 ;
#     wiki:id "Q23983664" .
#
# knowGL:Demonstration a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "demonstration" ;
#     owl:sameAs wiki:Q175331 ;
#     wiki:id "Q175331" .
#
# knowGL:DepartmentStoreChain a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "department store chain" ;
#     owl:sameAs wiki:Q2549179 ;
#     wiki:id "Q2549179" .
#
# knowGL:Depletion a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "depletion" ;
#     owl:sameAs wiki:Q5260663 ;
#     wiki:id "Q5260663" .
#
# knowGL:Depression a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "depression" ;
#     owl:sameAs wiki:Q42844 ;
#     wiki:id "Q42844" .
#
# knowGL:Desert a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "desert" ;
#     owl:sameAs wiki:Q8514 ;
#     wiki:id "Q8514" .
#
# knowGL:Development a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "development" ;
#     owl:sameAs wiki:Q1074523 ;
#     wiki:id "Q1074523" .
#
# knowGL:Device a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "device" ;
#     owl:sameAs wiki:Q3966 ;
#     wiki:id "Q3966" .
#
# knowGL:Diaspora a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "diaspora" ;
#     owl:sameAs wiki:Q133004 ;
#     wiki:id "Q133004" .
#
# knowGL:DirectiveOfTheEuropeanUnion a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "directive of the European Union" ;
#     owl:sameAs wiki:Q326124 ;
#     wiki:id "Q326124" .
#
# knowGL:DirectorOfBureau a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "Director of Bureau" ;
#     owl:sameAs wiki:Q23931359 ;
#     wiki:id "Q23931359" .
#
# knowGL:Disaster a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "disaster" ;
#     owl:sameAs wiki:Q3839081 ;
#     wiki:id "Q3839081" .
#
# knowGL:Discrimination a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "discrimination" ;
#     owl:sameAs wiki:Q169207 ;
#     wiki:id "Q169207" .
#
# knowGL:Disease a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "disease" ;
#     owl:sameAs wiki:Q12136 ;
#     wiki:id "Q12136" .
#
# knowGL:DisplacedPerson a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "displaced person" ;
#     owl:sameAs wiki:Q706601 ;
#     wiki:id "Q706601" .
#
# knowGL:DisposableProduct a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "disposable product" ;
#     owl:sameAs wiki:Q1194058 ;
#     wiki:id "Q1194058" .
#
# knowGL:DistrictOfJapan a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "district of Japan" ;
#     owl:sameAs wiki:Q1122846 ;
#     wiki:id "Q1122846" .
#
# knowGL:DistrictOfMoldova a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "district of Moldova" ;
#     owl:sameAs wiki:Q15068450 ;
#     wiki:id "Q15068450" .
#
# knowGL:DistrictOfSyria a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "district of Syria" ;
#     owl:sameAs wiki:Q2915776 ;
#     wiki:id "Q2915776" .
#
# knowGL:DistrictOfTurkey a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "district of Turkey" ;
#     owl:sameAs wiki:Q1147395 ;
#     wiki:id "Q1147395" .
#
# knowGL:Diversity a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "diversity" ;
#     owl:sameAs wiki:Q27722602 ;
#     wiki:id "Q27722602" .
#
# knowGL:Document a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "document" ;
#     owl:sameAs wiki:Q49848 ;
#     wiki:id "Q49848" .
#
# knowGL:DogBreed a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "dog breed" ;
#     owl:sameAs wiki:Q39367 ;
#     wiki:id "Q39367" .
#
# knowGL:Dot-comCompany a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "dot-com company" ;
#     owl:sameAs wiki:Q1194970 ;
#     wiki:id "Q1194970" .
#
# knowGL:Dramatico-musicalWork a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "dramatico-musical work" ;
#     owl:sameAs wiki:Q58483083 ;
#     wiki:id "Q58483083" .
#
# knowGL:Drug a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "drug" ;
#     owl:sameAs wiki:Q12140 ;
#     wiki:id "Q12140" .
#
# knowGL:DryToilet a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "dry toilet" ;
#     owl:sameAs wiki:Q18352682 ;
#     wiki:id "Q18352682" .
#
# knowGL:Dyad a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "dyad" ;
#     owl:sameAs wiki:Q29431432 ;
#     wiki:id "Q29431432" .
#
# knowGL:Dye a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "dye" ;
#     owl:sameAs wiki:Q189720 ;
#     wiki:id "Q189720" .
#
# knowGL:ERPSoftware a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "ERP software" ;
#     owl:sameAs wiki:Q28057030 ;
#     wiki:id "Q28057030" .
#
# knowGL:EarthObservationSatellite a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "Earth observation satellite" ;
#     owl:sameAs wiki:Q854845 ;
#     wiki:id "Q854845" .
#
# knowGL:Earthquake a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "earthquake" ;
#     owl:sameAs wiki:Q7944 ;
#     wiki:id "Q7944" .
#
# knowGL:EconomicActivity a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "economic activity" ;
#     owl:sameAs wiki:Q8187769 ;
#     wiki:id "Q8187769" .
#
# knowGL:EconomicConcept a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "economic concept" ;
#     owl:sameAs wiki:Q29028649 ;
#     wiki:id "Q29028649" .
#
# knowGL:EconomicCrisis a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "economic crisis" ;
#     owl:sameAs wiki:Q114380 ;
#     wiki:id "Q114380" .
#
# knowGL:EconomicEfficiency a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "economic efficiency" ;
#     owl:sameAs wiki:Q615445 ;
#     wiki:id "Q615445" .
#
# knowGL:EconomicGrowth a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "economic growth" ;
#     owl:sameAs wiki:Q189833 ;
#     wiki:id "Q189833" .
#
# knowGL:EconomicIndicator a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "economic indicator" ;
#     owl:sameAs wiki:Q1167393 ;
#     wiki:id "Q1167393" .
#
# knowGL:EconomicMiracle a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "economic miracle" ;
#     owl:sameAs wiki:Q11692772 ;
#     wiki:id "Q11692772" .
#
# knowGL:EconomicSector a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "economic sector" ;
#     owl:sameAs wiki:Q3958441 ;
#     wiki:id "Q3958441" .
#
# knowGL:Economics a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "economics" ;
#     owl:sameAs wiki:Q8134 ;
#     wiki:id "Q8134" .
#
# knowGL:Economy a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "economy" ;
#     owl:sameAs wiki:Q159810 ;
#     wiki:id "Q159810" .
#
# knowGL:EconomyOfJapan a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "economy of Japan" ;
#     owl:sameAs wiki:Q319831 ;
#     wiki:id "Q319831" .
#
# knowGL:Ecosystem a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "ecosystem" ;
#     owl:sameAs wiki:Q37813 ;
#     wiki:id "Q37813" .
#
# knowGL:Education a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "education" ;
#     owl:sameAs wiki:Q8434 ;
#     wiki:id "Q8434" .
#
# knowGL:EducationInCountryOrRegion a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "education in country or region" ;
#     owl:sameAs wiki:Q64801076 ;
#     wiki:id "Q64801076" .
#
# knowGL:Effectiveness a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "effectiveness" ;
#     owl:sameAs wiki:Q1296024 ;
#     wiki:id "Q1296024" .
#
# knowGL:Elastomer a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "elastomer" ;
#     owl:sameAs wiki:Q252266 ;
#     wiki:id "Q252266" .
#
# knowGL:ElectoralDistrict a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "electoral district" ;
#     owl:sameAs wiki:Q192611 ;
#     wiki:id "Q192611" .
#
# knowGL:ElectromagneticRadiation a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "electromagnetic radiation" ;
#     owl:sameAs wiki:Q12969754 ;
#     wiki:id "Q12969754" .
#
# knowGL:ElectromagneticWave a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "electromagnetic wave" ;
#     owl:sameAs wiki:Q11386 ;
#     wiki:id "Q11386" .
#
# knowGL:ElectronicMachine a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "electronic machine" ;
#     owl:sameAs wiki:Q2858615 ;
#     wiki:id "Q2858615" .
#
# knowGL:Encryption a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "encryption" ;
#     owl:sameAs wiki:Q141090 ;
#     wiki:id "Q141090" .
#
# knowGL:EndOfAnEra a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "end of an era" ;
#     owl:sameAs wiki:Q300386 ;
#     wiki:id "Q300386" .
#
# knowGL:Energy a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "energy" ;
#     owl:sameAs wiki:Q11379 ;
#     wiki:id "Q11379" .
#
# knowGL:EngineeringProcess a knowGL:Type,
#         rdfs:Class ;
#     rdfs:label "engineering process" ;
#     owl:sameAs wiki:Q500669 ;
# ...
#         knowGL:performance_chemicals,
#         knowGL:pharmaceuticals,
#         knowGL:plastics ;
#     knowGL:instanceOf knowGL:market_capitalization,
#         knowGL:multinational_company,
#         knowGL:subsidiary ;
#     knowGL:investor knowGL:blackrock ;
#     knowGL:legalForm knowGL:public_company ;
#     knowGL:memberOf knowGL:greenpeace ;
#     knowGL:ownedBy knowGL:blackrock,
#         knowGL:monsanto ;
#     knowGL:ownerOf knowGL:ammonia,
#         knowGL:basfbranded,
#         knowGL:bayer_ag,
#         knowGL:blackrock,
#         knowGL:cognis,
#         knowGL:engelhard_corporation,
#         knowGL:herbol,
#         knowGL:inge_gmbh,
#         knowGL:ludwigshafen,
#         knowGL:monsanto,
#         knowGL:schwarzheide,
#         knowGL:wintershall_dea,
#         knowGL:wyandotte_chemical_company ;
#     knowGL:parentOrganization knowGL:bayer,
#         knowGL:bayer_ag,
#         knowGL:blackrock ;
#     knowGL:replaces knowGL:ig_farben ;
#     knowGL:revenue knowGL:annual_revenue,
#         knowGL:earnings,
#         <http://example.org/ibm-KnowGL/#eur€641_billion> ;
#     knowGL:revenuePershare <http://example.org/ibm-KnowGL/#eur€> ;
#     knowGL:stockMarketcapitalization <http://example.org/ibm-KnowGL/#us€631 billion>,
#         <http://example.org/ibm-KnowGL/#us€637 billion> ;
#     owl:sameAs wiki:Q9401 ;
#     wiki:id "Q9401" .
#
# knowGL:europe a knowGL:Continent,
#         knowGL:Entity,
#         knowGL:NationalEconomy,
#         rdfs:Resource ;
#     rdfs:label "Economy of Moldova",
#         "Europe" ;
#     knowGL:instanceOf knowGL:europe ;
#     knowGL:partOf knowGL:central_europe ;
#     owl:sameAs wiki:Q46 ;
#     wiki:id "Q46" .
#
# knowGL:stratosphere a knowGL:AtmosphericLayer,
#         knowGL:Entity,
#         rdfs:Resource ;
#     rdfs:label " stratosphere",
#         "Stratosphere",
#         "stratosphere" ;
#     knowGL:continent knowGL:antarctica ;
#     knowGL:followedBy knowGL:troposphere ;
#     knowGL:follows knowGL:troposphere ;
#     knowGL:madeFrommaterial knowGL:nitrogen_oxides ;
#     knowGL:partOf knowGL:atmosphere,
#         knowGL:atmospheric_circulation,
#         knowGL:lower_atmosphere,
#         knowGL:stratosphere,
#         knowGL:troposphere ;
#     owl:sameAs wiki:Q108376 ;
#     wiki:id "108376",
#         "Q108376" .
#
# wiki:Q46 wiki:P150 wiki:Q212 ;
#     wiki:P31 wiki:Q35798,
#         wiki:Q46,
#         wiki:Q5107,
#         wiki:Q6456916,
#         wiki:Q7210356 ;
#     wiki:P361 wiki:Q27509,
#         wiki:Q46,
#         wiki:Q48 .
#
# wiki:Q43229 wiki:P31 wiki:Q163740,
#         wiki:Q4830453 .
#
# wiki:Q515 wiki:P31 wiki:Q486972 .
#
# wiki:Q212 wiki:P102 wiki:Q1065,
#         wiki:Q132551,
#         wiki:Q161718,
#         wiki:Q1969730,
#         wiki:Q20857240,
#         wiki:Q458,
#         wiki:Q46,
#         wiki:Q472311,
#         wiki:Q484652,
#         wiki:Q50534548,
#         wiki:Q7159,
#         wiki:Q7184,
#         wiki:Q7785,
#         wiki:Q81299,
#         wiki:Q8752,
#         wiki:Q8896 ;
#     wiki:P1336 wiki:Q159 ;
#     wiki:P1344 wiki:Q178810,
#         wiki:Q467011 ;
#     wiki:P138 wiki:Q974724 ;
#     wiki:P1412 wiki:Q150,
#         wiki:Q315,
#         wiki:Q8798 ;
#     wiki:P150 wiki:Q1196,
#         wiki:Q1773,
#         wiki:Q1899,
#         wiki:Q36036,
#         wiki:Q37133,
#         wiki:Q37333,
#         wiki:Q42308,
#         wiki:Q43070,
#         wiki:Q48256,
#         wiki:Q5545,
#         wiki:Q974724 ;
#     wiki:P172 wiki:Q13201,
#         wiki:Q1976298,
#         wiki:Q24089934,
#         wiki:Q40477,
#         wiki:Q41,
#         wiki:Q44806,
#         wiki:Q467,
#         wiki:Q49542,
#         wiki:Q7878531,
#         wiki:Q8060,
#         wiki:Q8798 ;
#     wiki:P1830 wiki:Q923337 ;
#     wiki:P1906 wiki:Q30461,
#         wiki:Q579677 ;
#     wiki:P208 wiki:Q2991162,
#         wiki:Q613729,
#         wiki:Q7188 ;
#     wiki:P2184 wiki:Q17983886,
#         wiki:Q309 ;
#     wiki:P30 wiki:Q46,
#         wiki:Q50534548 ;
#     wiki:P31 wiki:Q3624078,
#         wiki:Q6256 ;
#     wiki:P36 wiki:Q37333 ;
#     wiki:P361 wiki:Q12585,
#         wiki:Q27468,
#         wiki:Q27509,
#         wiki:Q45,
#         wiki:Q46,
#         wiki:Q50534548,
#         wiki:Q900636 ;
#     wiki:P47 wiki:Q1196,
#         wiki:Q1208,
#         wiki:Q142,
#         wiki:Q145,
#         wiki:Q150,
#         wiki:Q159,
#         wiki:Q17,
#         wiki:Q183,
#         wiki:Q188,
#         wiki:Q189,
#         wiki:Q191,
#         wiki:Q1969730,
#         wiki:Q203323,
#         wiki:Q211,
#         wiki:Q211201,
#         wiki:Q212,
#         wiki:Q213,
#         wiki:Q214,
#         wiki:Q218,
#         wiki:Q219,
#         wiki:Q30,
#         wiki:Q34,
#         wiki:Q35,
#         wiki:Q36,
#         wiki:Q39,
#         wiki:Q43,
#         wiki:Q45,
#         wiki:Q458,
#         wiki:Q5146,
#         wiki:Q55,
#         wiki:Q664,
#         wiki:Q7737,
#         wiki:Q77672997,
#         wiki:Q79,
#         wiki:Q801,
#         wiki:Q809,
#         wiki:Q842438,
#         wiki:Q8752,
#         wiki:Q878,
#         wiki:Q9035 ;
#     wiki:P793 wiki:Q110999040,
#         wiki:Q131572,
#         wiki:Q178810,
#         wiki:Q381072,
#         wiki:Q467011 .
#
# knowGL:ukraine a knowGL:Entity,
#         knowGL:SovereignState,
#         rdfs:Resource ;
#     rdfs:label "Russia",
#         "Ukraine" ;
#     knowGL:capital knowGL:lublin ;
#     knowGL:containsAdministrativeterritorialEntity knowGL:dnipro,
#         knowGL:donetsk,
#         knowGL:kharkiv,
#         knowGL:kiev,
#         knowGL:lublin,
#         knowGL:lviv,
#         knowGL:mariupol,
#         knowGL:mecklenburgvorpommern,
#         knowGL:penza_oblast,
#         knowGL:pour_lukraine,
#         knowGL:riga ;
#     knowGL:continent knowGL:europe,
#         knowGL:european,
#         knowGL:european_country ;
#     knowGL:ethnicGroup knowGL:ethnic_greek,
#         knowGL:ethnic_greek_community,
#         knowGL:greek,
#         knowGL:greek_community,
#         knowGL:nonukrainian,
#         knowGL:nonukrainian_nationals,
#         knowGL:nonukrainians,
#         knowGL:romani,
#         knowGL:romani_people,
#         knowGL:russians,
#         knowGL:slavs,
#         knowGL:ukrainian,
#         knowGL:ukrainian_citizen,
#         knowGL:ukrainian_citizens,
#         knowGL:ukrainian_people,
#         knowGL:ukrainiancanadians,
#         knowGL:ukrainians,
#         knowGL:women ;
#     knowGL:executiveBody knowGL:federal_government,
#         knowGL:government,
#         knowGL:government_of_ukraine,
#         knowGL:stateprovided_accommodation ;
#     knowGL:historyOftopic knowGL:history,
#         knowGL:shared_history ;
#     knowGL:instanceOf knowGL:country ;
#     knowGL:languageUsed knowGL:french,
#         knowGL:language,
#         knowGL:ukrainian ;
#     knowGL:memberOf knowGL:african_union,
#         knowGL:commonwealth_of_nations,
#         knowGL:council_of_the_eu,
#         knowGL:eu,
#         knowGL:european,
#         knowGL:european_country,
#         knowGL:european_migrant_crisis,
#         knowGL:european_union,
#         knowGL:international_organization,
#         knowGL:international_organization_for_migration,
#         knowGL:nato,
#         knowGL:organization_for_security_and_cooperation_in_europe,
#         knowGL:schengen,
#         knowGL:schengen_area,
#         knowGL:schengen_countries,
#         knowGL:schengen_zone,
#         knowGL:un,
#         knowGL:un_high_commission_for_human_rights,
#         knowGL:undp,
#         knowGL:unhcr,
#         knowGL:united_nations ;
#     knowGL:namedAfter knowGL:pour_lukraine ;
#     knowGL:officeHeldbyHeadofState knowGL:president,
#         knowGL:president_of_ukraine ;
#     knowGL:ownerOf knowGL:ukraines_airspace,
#         knowGL:ukrainian_railways ;
#     knowGL:partOf knowGL:central_and_eastern_europe,
#         knowGL:central_europe,
#         knowGL:eastern_europe,
#         knowGL:europe,
#         knowGL:european,
#         knowGL:european_country,
#         knowGL:latin_america,
#         knowGL:portugal ;
#     knowGL:participantIn knowGL:invasion,
#         knowGL:syrian_civil_war ;
#     knowGL:sharesBorderwith knowGL:brandenburg,
#         knowGL:british,
#         knowGL:bulgaria,
#         knowGL:czech_republic,
#         knowGL:danish,
#         knowGL:denmark,
#         knowGL:egypt,
#         knowGL:estonia,
#         knowGL:eu,
#         knowGL:european_union,
#         knowGL:france,
#         knowGL:french,
#         knowGL:german,
#         knowGL:germany,
#         knowGL:iceland,
#         knowGL:israel,
#         knowGL:japan,
#         knowGL:latvia,
#         knowGL:mecklenburgvorpommern,
#         knowGL:netherlands,
#         knowGL:new_zealand,
#         knowGL:other_states,
#         knowGL:poland,
#         knowGL:polish,
#         knowGL:portugal,
#         knowGL:portuguese,
#         knowGL:romania,
#         knowGL:russia,
#         knowGL:russian,
#         knowGL:russian_federation,
#         knowGL:schengen,
#         knowGL:slovakia,
#         knowGL:soviet,
#         knowGL:sweden,
#         knowGL:switzerland,
#         knowGL:turkey,
#         knowGL:uk,
#         knowGL:ukraine,
#         knowGL:ukraines,
#         knowGL:ukraines_airspace,
#         knowGL:united_arab_emirates,
#         knowGL:united_states ;
#     knowGL:significantEvent knowGL:crisis,
#         knowGL:invasion,
#         knowGL:refugee,
#         knowGL:russian_invasion,
#         knowGL:russias_invasion_of_ukraine,
#         knowGL:syrian_civil_war ;
#     knowGL:territoryClaimedby knowGL:russia ;
#     owl:sameAs wiki:Q212 ;
#     wiki:id "Q212" .
#
# wiki:Q3895 wiki:P102 wiki:Q1788081 ;
#     wiki:P1037 wiki:Q2627090,
#         wiki:Q71147 ;
#     wiki:P127 wiki:Q1788081,
#         wiki:Q232812,
#         wiki:Q252,
#         wiki:Q3895,
#         wiki:Q483915,
#         wiki:Q698467,
#         wiki:Q779722,
#         wiki:Q7865813 ;
#     wiki:P1365 wiki:Q35255,
#         wiki:Q466183,
#         wiki:Q64755654,
#         wiki:Q76751,
#         wiki:Q779722 ;
#     wiki:P138 wiki:Q76751 ;
#     wiki:P1416 wiki:Q1788081 ;
#     wiki:P1454 wiki:Q12049274,
#         wiki:Q167270,
#         wiki:Q2746361,
#         wiki:Q3895,
#         wiki:Q4830453,
#         wiki:Q779722,
#         wiki:Q850210 ;
#     wiki:P155 wiki:Q1143000,
#         wiki:Q157064,
#         wiki:Q35255,
#         wiki:Q466183,
#         wiki:Q64755654,
#         wiki:Q76751,
#         wiki:Q779722 ;
#     wiki:P159 wiki:Q1615401,
#         wiki:Q1726,
#         wiki:Q252,
#         wiki:Q3895,
#         wiki:Q84,
#         wiki:Q90 ;
#     wiki:P169 wiki:Q2627090,
#         wiki:Q64755654,
#         wiki:Q71147 ;
#     wiki:P1830 wiki:Q1156897,
#         wiki:Q1195237,
#         wiki:Q1415635,
#         wiki:Q157064,
#         wiki:Q15789,
#         wiki:Q232812,
#         wiki:Q24942022,
#         wiki:Q251068,
#         wiki:Q2824455,
#         wiki:Q3109995,
#         wiki:Q35127,
#         wiki:Q35255,
#         wiki:Q357017,
#         wiki:Q3746269,
#         wiki:Q3895,
#         wiki:Q466183,
#         wiki:Q4682708,
#         wiki:Q483915,
#         wiki:Q64755654,
#         wiki:Q7380124,
#         wiki:Q7462919,
#         wiki:Q7798009,
#         wiki:Q7865813 ;
#     wiki:P1889 wiki:Q35255 ;
#     wiki:P199 wiki:Q232812,
#         wiki:Q35255,
#         wiki:Q357048,
#         wiki:Q3895 ;
#     wiki:P2541 wiki:Q408 ;
#     wiki:P31 wiki:Q12049274,
#         wiki:Q167270,
#         wiki:Q2746361,
#         wiki:Q39809,
#         wiki:Q4830453 ;
#     wiki:P452 wiki:Q11460,
#         wiki:Q118279254,
#         wiki:Q1381731,
#         wiki:Q161928,
#         wiki:Q2736,
#         wiki:Q28188413,
#         wiki:Q39809,
#         wiki:Q431289,
#         wiki:Q452421 ;
#     wiki:P495 wiki:Q252,
#         wiki:Q408,
#         wiki:Q664,
#         wiki:Q668,
#         wiki:Q842438 ;
#     wiki:P5056 wiki:Q7798009 ;
#     wiki:P625 wiki:Q252,
#         wiki:Q84 ;
#     wiki:P641 wiki:Q2736,
#         wiki:Q5372,
#         wiki:Q5375,
#         wiki:Q5377 ;
#     wiki:P749 wiki:Q15789,
#         wiki:Q253414,
#         wiki:Q3895,
#         wiki:Q483915,
#         wiki:Q779722 ;
#     wiki:P800 wiki:Q1415635 ;
#     wiki:P859 wiki:Q1195237,
#         wiki:Q15789,
#         wiki:Q1788081,
#         wiki:Q183,
#         wiki:Q29,
#         wiki:Q615 .
#
# knowGL:adidas a knowGL:Business,
#         knowGL:Entity,
#         rdfs:Resource ;
#     rdfs:label "ADidas",
#         "Adidas",
#         "Adidas Golf",
#         "adidas" ;
#     knowGL:affiliation knowGL:new_zealand_rugby_union ;
#     knowGL:businessDivision knowGL:adidas,
#         knowGL:adidas_in_india,
#         knowGL:adidass,
#         knowGL:puma,
#         knowGL:stella_mccartney ;
#     knowGL:chiefExecutiveofficer knowGL:dave_thomas,
#         knowGL:herbert_hainer,
#         knowGL:louisdreyfus ;
#     knowGL:countryOforigin knowGL:australia,
#         knowGL:british,
#         knowGL:india,
#         knowGL:indonesia,
#         knowGL:new_zealand ;
#     knowGL:differentFrom knowGL:puma ;
#     knowGL:directorManager knowGL:dave_thomas,
#         knowGL:herbert_hainer ;
#     knowGL:follows knowGL:adi_dassler,
#         knowGL:crédit_lyonnais,
#         knowGL:fitness_world_trading,
#         knowGL:karhu_sports,
#         knowGL:louisdreyfus,
#         knowGL:puma,
#         knowGL:puma_se,
#         knowGL:pumas,
#         knowGL:reebok ;
#     knowGL:headquartersLocation knowGL:adidas,
#         knowGL:herzogenaurach,
#         knowGL:herzogenaurach_bavaria,
#         knowGL:herzogenaurach_germany,
#         knowGL:indonesia,
#         knowGL:london,
#         knowGL:munich,
#         knowGL:paris ;
#     knowGL:industry knowGL:apparel,
#         knowGL:association_football,
#         knowGL:brand,
#         knowGL:clothing,
#         knowGL:collective_bargaining,
#         knowGL:football,
#         knowGL:football_kit,
#         knowGL:football_kits,
#         knowGL:footwear,
#         knowGL:labour_standards,
#         knowGL:public_relations,
#         knowGL:sports_bras ;
#     knowGL:instanceOf knowGL:business,
#         knowGL:public_relations,
#         knowGL:retailer,
#         knowGL:retailers,
#         knowGL:sports_stores,
#         knowGL:trademark ;
#     knowGL:legalForm knowGL:adidas,
#         knowGL:business,
#         knowGL:crédit_lyonnais,
#         knowGL:retailer,
#         knowGL:retailers,
#         knowGL:revenue,
#         knowGL:trademark ;
#     knowGL:location knowGL:indonesia,
#         knowGL:london ;
#     knowGL:memberOf knowGL:fifa_youth_group,
#         knowGL:new_zealand_rugby_union ;
#     knowGL:namedAfter knowGL:adolf_adi_dassler ;
#     knowGL:notableWork knowGL:sweatshop ;
#     knowGL:operatingArea knowGL:australia ;
#     knowGL:ownedBy knowGL:adidas,
#         knowGL:crédit_lyonnais,
#         knowGL:indonesia,
#         knowGL:new_zealand_rugby_union,
#         knowGL:nike,
#         knowGL:stella_mccartney,
#         knowGL:usa_gymnastics,
#         knowGL:yue_yuen_industrial_holdings ;
#     knowGL:ownerOf knowGL:3stripe_logo,
#         knowGL:adidas,
#         knowGL:adidas_1,
#         knowGL:adidas_eqt,
#         knowGL:adidas_finale,
#         knowGL:adidas_in_india,
#         knowGL:adidas_lacrosse,
#         knowGL:adidas_price_tag,
#         knowGL:adidas_trademark,
#         knowGL:adilette,
#         knowGL:adizero,
#         knowGL:alexander_wang,
#         knowGL:bayern_münchen,
#         knowGL:five_ten,
#         knowGL:football_kits,
#         knowGL:gold_coast_titans,
#         knowGL:karhu_sports,
#         knowGL:kizone,
#         knowGL:line_of_soviet_themed_items,
#         knowGL:louisdreyfus,
#         knowGL:micoach,
#         knowGL:mumbai_indians,
#         knowGL:nike,
#         knowGL:pt_kizone,
#         knowGL:puma,
#         knowGL:puma_se,
#         knowGL:reebok,
#         knowGL:royal_challengers_bangalore,
#         knowGL:runtastic,
#         knowGL:stella_mccartney,
#         knowGL:superstar,
#         knowGL:sweatshop,
#         knowGL:sweatshops,
#         knowGL:three_stripes,
#         knowGL:usa_gymnastics,
#         knowGL:website ;
#     knowGL:parentOrganization knowGL:adidas,
#         knowGL:bayern_münchen,
#         knowGL:crédit_lyonnais,
#         knowGL:fifa,
#         knowGL:fifa_youth_group,
#         knowGL:nike ;
#     knowGL:patronymOrmatronymForthisPerson knowGL:three_stripes ;
#     knowGL:replaces knowGL:adi_dassler,
#         knowGL:crédit_lyonnais,
#         knowGL:louisdreyfus,
#         knowGL:puma,
#         knowGL:reebok ;
#     knowGL:sponsor knowGL:bayern_münchen,
#         knowGL:germany,
#         knowGL:lionel_messi,
#         knowGL:mumbai_indians,
#         knowGL:new_zealand_rugby_union,
#         knowGL:spain ;
#     knowGL:sport knowGL:association_football,
#         knowGL:basketball,
#         knowGL:cricket,
#         knowGL:football,
#         knowGL:golf ;
#     owl:sameAs wiki:Q3895 ;
#     wiki:id "3895",
#         "Q3895" .
#
# wiki:Q4830453 wiki:P31 wiki:Q167270,
#         wiki:Q43229 .

# %%
# let's save the graph
g.serialize(destination="KGs/extracted_graph_for_enexa_hackathon_LLM_KnowGL.ttl", format="turtle")
# Out:
# <Graph identifier=N7f6396057093481da373edbc237d797b (<class 'rdflib.graph.Graph'>)>
